# %%
import tensorflow as tf
from keras import backend as K
from keras.models import Sequential
from keras.layers.convolutional import Conv2D 
from keras.layers.convolutional import AveragePooling2D
from keras.layers.core import Activation, Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.datasets import mnist
from keras.utils import np_utils
from keras.optimizers import SGD, RMSprop, Adam
import matplotlib.pyplot as plt
from keras.callbacks import TensorBoard
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import ModelCheckpoint
from keras.engine.topology import Layer, InputSpec
from keras.layers import Input, Permute,  Reshape
from keras.models import Model
from keras.layers.recurrent import LSTM
from keras.layers.wrappers import Bidirectional, TimeDistributed
from keras.layers import merge, Multiply

#K.set_image_dim_ordering("th")
SINGLE_ATTENTION_VECTOR = False


def attention_3d_block(inputs,timesteps):
    # inputs.shape = (batch_size, time_steps, input_dim)
    input_dim = int(inputs.shape[2])
    time_steps=timesteps
    print(input_dim)
    print(time_steps)
    a = Permute((2, 1))(inputs)
    #a = Reshape((input_dim, time_steps))(a) # this line is not useful. It's just to know which dimension is what.
    a = Dense(time_steps, activation='softmax')(a)
    if SINGLE_ATTENTION_VECTOR:
        a = Lambda(lambda x: K.mean(x, axis=1))(a) #, name='dim_reduction'
        a = RepeatVector(input_dim)(a)
    a_probs = Permute((2, 1))(a) #, name='attention_vec ' % (depth)
    #output_attention_mul = merge([inputs, a_probs], name='attention_mul', mode='mul')
    output_attention_mul= Multiply()([inputs, a_probs]) #name='attention_mul'
    return output_attention_mul


class LSTMATTBFnet:
    @staticmethod
    def build(timeSteps,variables,classes):
        inputNet = Input(shape=(timeSteps,variables)) #batch_shape=(20, 7, 5) 
        #lstm=Bidirectional(LSTM(100,recurrent_dropout=0.4,dropout=0.4),merge_mode='concat')(inputNet) #worse using stateful=True

        lstm=LSTM(100,recurrent_dropout=0.1,dropout=0.1,return_sequences=True)(inputNet) #worse using stateful=True 
        attention_mul = attention_3d_block(lstm,timeSteps)
        attention_mul = Flatten()(attention_mul)
        # a softmax classifier
        classificationLayer=Dense(classes,activation='softmax')(attention_mul)
        
        model=Model(inputNet,classificationLayer)
        return model

# %%
# load data
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split


def non_shuffling_train_test_split(X, y, test_size=0.2):
    i = int((1 - test_size) * X.shape[0]) + 1
    X_train, X_test = np.split(X, [i])
    y_train, y_test = np.split(y, [i])
    return X_train, X_test, y_train, y_test

# load all data
dfin = pd.read_csv('windows-size72-step12.csv',header=None)  #inputs 72 lines per sample
dfout = pd.read_csv('out-class-size72-step12.csv',header=None)  #output classes 

total_inputs,total_output = dfin.values.astype(np.float32),dfout.values.astype(np.int32)

# normalize
scaler = MinMaxScaler(feature_range=(0, 1))
total_inputs = scaler.fit_transform(total_inputs)

# every 72 lines is one input sample
total_inputs = np.reshape(total_inputs, (-1,72,8))
print("############# total shapes #############")
print(total_inputs.shape)
print(total_output.size)

train_inputs, test_inputs, train_output, test_output = non_shuffling_train_test_split(total_inputs, total_output, test_size=0.2)
#train_inputs, test_inputs, train_output, test_output = train_test_split(total_inputs, total_output, test_size=0.20, random_state=42)
print("############# train shapes #############")
print(train_inputs.shape)
print(train_output.shape)

print("############# test shapes #############")
print(test_inputs.shape)
print(test_output.shape)
# Out:
# ############# total shapes #############
# (2876, 72, 8)
# 2876
# ############# train shapes #############
# (2301, 72, 8)
# (2301, 1)
# ############# test shapes #############
# (575, 72, 8)
# (575, 1)

# %%
IMG_ROWS, IMG_COLS = 72, 8 # input image dimensions
NB_CLASSES = 5  # number of outputs = number of classes

X_train = train_inputs
y_train = np_utils.to_categorical(train_output, NB_CLASSES)
X_test = test_inputs
y_test = np_utils.to_categorical(test_output, NB_CLASSES)
print(y_test.shape)

OPTIMIZER = Adam()

model = LSTMATTBFnet.build(timeSteps=IMG_ROWS,variables=IMG_COLS,classes=NB_CLASSES)
model.compile(loss="categorical_crossentropy", optimizer=OPTIMIZER,
	metrics=["accuracy"])

model.summary()
# Out:
# (575, 5)
# 100
# 72
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 72, 8)]      0
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 72, 100)      43600       input_1[0][0]
# __________________________________________________________________________________________________
# permute (Permute)               (None, 100, 72)      0           lstm[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100, 72)      5256        permute[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 72, 100)      0           dense[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 72, 100)      0           lstm[0][0]
#                                                                  permute_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 7200)         0           multiply[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 5)            36005       flatten[0][0]
# ==================================================================================================
# Total params: 84,861
# Trainable params: 84,861
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from IPython.display import SVG,display
from keras.utils.vis_utils import model_to_dot
modelSVG=SVG(model_to_dot(model,show_shapes=True).create(prog='dot', format='svg'))
display(modelSVG)

# %%
NB_EPOCH = 100
BATCH_SIZE = 64
VERBOSE = 1

#tbCallBack = TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True)
#esCallBack = EarlyStopping(monitor='val_acc', min_delta=0, patience=12, verbose=0, mode='max')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.01,patience=5, min_lr=0.0001)
best_checkpoint = ModelCheckpoint('LSTM-ATTENTION-BF-polution.h5', monitor='val_accuracy', save_best_only=True, verbose=1)

history = model.fit(X_train, y_train, 
		batch_size=BATCH_SIZE, epochs=NB_EPOCH, 
		verbose=1, # 0 for no logging to stdout, 1 for progress bar logging, 2 for one log line per epoch.
		validation_data=(X_test,y_test),
		#validation_split=VALIDATION_SPLIT,
		callbacks=[reduce_lr,best_checkpoint])
# Out:
# Epoch 1/100
# 36/36 [==============================] - ETA: 0s - loss: 1.5901 - accuracy: 0.2395
# Epoch 00001: val_accuracy improved from -inf to 0.22609, saving model to LSTM-ATTENTION-BF-polution.h5
# 36/36 [==============================] - 6s 174ms/step - loss: 1.5901 - accuracy: 0.2395 - val_loss: 1.5804 - val_accuracy: 0.2261
# Epoch 2/100
# 36/36 [==============================] - ETA: 0s - loss: 1.4957 - accuracy: 0.3451
# Epoch 00002: val_accuracy improved from 0.22609 to 0.25043, saving model to LSTM-ATTENTION-BF-polution.h5
# 36/36 [==============================] - 6s 163ms/step - loss: 1.4957 - accuracy: 0.3451 - val_loss: 1.4988 - val_accuracy: 0.2504
# Epoch 3/100
# 36/36 [==============================] - ETA: 0s - loss: 1.4446 - accuracy: 0.3646
# Epoch 00003: val_accuracy improved from 0.25043 to 0.27478, saving model to LSTM-ATTENTION-BF-polution.h5
# 36/36 [==============================] - 6s 163ms/step - loss: 1.4446 - accuracy: 0.3646 - val_loss: 1.4883 - val_accuracy: 0.2748
# Epoch 4/100
# 36/36 [==============================] - ETA: 0s - loss: 1.4280 - accuracy: 0.3733
# Epoch 00004: val_accuracy improved from 0.27478 to 0.28174, saving model to LSTM-ATTENTION-BF-polution.h5
# 36/36 [==============================] - 6s 163ms/step - loss: 1.4280 - accuracy: 0.3733 - val_loss: 1.4806 - val_accuracy: 0.2817
# Epoch 5/100
# 36/36 [==============================] - ETA: 0s - loss: 1.4231 - accuracy: 0.3764
# Epoch 00005: val_accuracy did not improve from 0.28174
# 36/36 [==============================] - 6s 163ms/step - loss: 1.4231 - accuracy: 0.3764 - val_loss: 1.4674 - val_accuracy: 0.2800
# Epoch 6/100
# 36/36 [==============================] - ETA: 0s - loss: 1.4131 - accuracy: 0.3855
# Epoch 00006: val_accuracy improved from 0.28174 to 0.30783, saving model to LSTM-ATTENTION-BF-polution.h5
# 36/36 [==============================] - 6s 164ms/step - loss: 1.4131 - accuracy: 0.3855 - val_loss: 1.4909 - val_accuracy: 0.3078
# Epoch 7/100
# 36/36 [==============================] - ETA: 0s - loss: 1.4171 - accuracy: 0.3803
# Epoch 00007: val_accuracy did not improve from 0.30783
# 36/36 [==============================] - 6s 161ms/step - loss: 1.4171 - accuracy: 0.3803 - val_loss: 1.4983 - val_accuracy: 0.2609
# Epoch 8/100
# 36/36 [==============================] - ETA: 0s - loss: 1.4115 - accuracy: 0.3790
# Epoch 00008: val_accuracy did not improve from 0.30783
# 36/36 [==============================] - 6s 161ms/step - loss: 1.4115 - accuracy: 0.3790 - val_loss: 1.4699 - val_accuracy: 0.3078
# Epoch 9/100
# 36/36 [==============================] - ETA: 0s - loss: 1.4065 - accuracy: 0.3837
# Epoch 00009: val_accuracy improved from 0.30783 to 0.33043, saving model to LSTM-ATTENTION-BF-polution.h5
# 36/36 [==============================] - 6s 164ms/step - loss: 1.4065 - accuracy: 0.3837 - val_loss: 1.4642 - val_accuracy: 0.3304
# Epoch 10/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3953 - accuracy: 0.3916
# Epoch 00010: val_accuracy did not improve from 0.33043
# 36/36 [==============================] - 6s 162ms/step - loss: 1.3953 - accuracy: 0.3916 - val_loss: 1.4613 - val_accuracy: 0.3270
# Epoch 11/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3961 - accuracy: 0.3929
# Epoch 00011: val_accuracy did not improve from 0.33043
# 36/36 [==============================] - 6s 162ms/step - loss: 1.3961 - accuracy: 0.3929 - val_loss: 1.4489 - val_accuracy: 0.3252
# Epoch 12/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3919 - accuracy: 0.3916
# Epoch 00012: val_accuracy improved from 0.33043 to 0.33217, saving model to LSTM-ATTENTION-BF-polution.h5
# 36/36 [==============================] - 6s 163ms/step - loss: 1.3919 - accuracy: 0.3916 - val_loss: 1.4309 - val_accuracy: 0.3322
# Epoch 13/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3814 - accuracy: 0.3937
# Epoch 00013: val_accuracy did not improve from 0.33217
# 36/36 [==============================] - 6s 161ms/step - loss: 1.3814 - accuracy: 0.3937 - val_loss: 1.4385 - val_accuracy: 0.3322
# Epoch 14/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3735 - accuracy: 0.3864
# Epoch 00014: val_accuracy improved from 0.33217 to 0.33565, saving model to LSTM-ATTENTION-BF-polution.h5
# 36/36 [==============================] - 6s 163ms/step - loss: 1.3735 - accuracy: 0.3864 - val_loss: 1.4472 - val_accuracy: 0.3357
# Epoch 15/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3626 - accuracy: 0.4007
# Epoch 00015: val_accuracy did not improve from 0.33565
# 36/36 [==============================] - 6s 163ms/step - loss: 1.3626 - accuracy: 0.4007 - val_loss: 1.4335 - val_accuracy: 0.3270
# Epoch 16/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3635 - accuracy: 0.3998
# Epoch 00016: val_accuracy improved from 0.33565 to 0.33739, saving model to LSTM-ATTENTION-BF-polution.h5
# 36/36 [==============================] - 6s 163ms/step - loss: 1.3635 - accuracy: 0.3998 - val_loss: 1.3996 - val_accuracy: 0.3374
# Epoch 17/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3554 - accuracy: 0.4042
# Epoch 00017: val_accuracy did not improve from 0.33739
# 36/36 [==============================] - 6s 162ms/step - loss: 1.3554 - accuracy: 0.4042 - val_loss: 1.4180 - val_accuracy: 0.3374
# Epoch 18/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3587 - accuracy: 0.3994
# Epoch 00018: val_accuracy improved from 0.33739 to 0.35652, saving model to LSTM-ATTENTION-BF-polution.h5
# 36/36 [==============================] - 6s 162ms/step - loss: 1.3587 - accuracy: 0.3994 - val_loss: 1.4382 - val_accuracy: 0.3565
# Epoch 19/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3532 - accuracy: 0.4146
# Epoch 00019: val_accuracy did not improve from 0.35652
# 36/36 [==============================] - 6s 163ms/step - loss: 1.3532 - accuracy: 0.4146 - val_loss: 1.3951 - val_accuracy: 0.3409
# Epoch 20/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3573 - accuracy: 0.4063
# Epoch 00020: val_accuracy did not improve from 0.35652
# 36/36 [==============================] - 6s 163ms/step - loss: 1.3573 - accuracy: 0.4063 - val_loss: 1.3984 - val_accuracy: 0.3443
# Epoch 21/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3419 - accuracy: 0.4129
# Epoch 00021: val_accuracy improved from 0.35652 to 0.38435, saving model to LSTM-ATTENTION-BF-polution.h5
# 36/36 [==============================] - 6s 162ms/step - loss: 1.3419 - accuracy: 0.4129 - val_loss: 1.3909 - val_accuracy: 0.3843
# Epoch 22/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3373 - accuracy: 0.4194
# Epoch 00022: val_accuracy did not improve from 0.38435
# 36/36 [==============================] - 6s 159ms/step - loss: 1.3373 - accuracy: 0.4194 - val_loss: 1.4065 - val_accuracy: 0.3339
# Epoch 23/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3343 - accuracy: 0.4133
# Epoch 00023: val_accuracy did not improve from 0.38435
# 36/36 [==============================] - 6s 158ms/step - loss: 1.3343 - accuracy: 0.4133 - val_loss: 1.4108 - val_accuracy: 0.3426
# Epoch 24/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3297 - accuracy: 0.4189
# Epoch 00024: val_accuracy did not improve from 0.38435
# 36/36 [==============================] - 6s 159ms/step - loss: 1.3297 - accuracy: 0.4189 - val_loss: 1.3907 - val_accuracy: 0.3617
# Epoch 25/100
# 36/36 [==============================] - ETA: 0s - loss: 1.
val_accuracy did not improve from 0.41391
# 36/36 [==============================] - 6s 164ms/step - loss: 1.1895 - accuracy: 0.4915 - val_loss: 1.3711 - val_accuracy: 0.3791
# Epoch 41/100
# 36/36 [==============================] - ETA: 0s - loss: 1.1940 - accuracy: 0.5002
# Epoch 00041: val_accuracy did not improve from 0.41391
# 36/36 [==============================] - 7s 200ms/step - loss: 1.1940 - accuracy: 0.5002 - val_loss: 1.3770 - val_accuracy: 0.3861
# Epoch 42/100
# 36/36 [==============================] - ETA: 0s - loss: 1.1723 - accuracy: 0.4898
# Epoch 00042: val_accuracy did not improve from 0.41391
# 36/36 [==============================] - 10s 275ms/step - loss: 1.1723 - accuracy: 0.4898 - val_loss: 1.4699 - val_accuracy: 0.3183
# Epoch 43/100
# 36/36 [==============================] - ETA: 0s - loss: 1.1838 - accuracy: 0.5033
# Epoch 00043: val_accuracy did not improve from 0.41391
# 36/36 [==============================] - 6s 159ms/step - loss: 1.1838 - accuracy: 0.5033 - val_loss: 1.3716 - val_accuracy: 0.3843
# Epoch 44/100
# 36/36 [==============================] - ETA: 0s - loss: 1.1696 - accuracy: 0.5007
# Epoch 00044: val_accuracy did not improve from 0.41391
# 36/36 [==============================] - 6s 160ms/step - loss: 1.1696 - accuracy: 0.5007 - val_loss: 1.3666 - val_accuracy: 0.3983
# Epoch 45/100
# 36/36 [==============================] - ETA: 0s - loss: 1.1309 - accuracy: 0.5280
# Epoch 00045: val_accuracy did not improve from 0.41391
# 36/36 [==============================] - 6s 160ms/step - loss: 1.1309 - accuracy: 0.5280 - val_loss: 1.3750 - val_accuracy: 0.3878
# Epoch 46/100
# 36/36 [==============================] - ETA: 0s - loss: 1.1188 - accuracy: 0.5189
# Epoch 00046: val_accuracy did not improve from 0.41391
# 36/36 [==============================] - 6s 159ms/step - loss: 1.1188 - accuracy: 0.5189 - val_loss: 1.3788 - val_accuracy: 0.4000
# Epoch 47/100
# 36/36 [==============================] - ETA: 0s - loss: 1.1105 - accuracy: 0.5472
# Epoch 00047: val_accuracy did not improve from 0.41391
# 36/36 [==============================] - 6s 161ms/step - loss: 1.1105 - accuracy: 0.5472 - val_loss: 1.3829 - val_accuracy: 0.3965
# Epoch 48/100
# 36/36 [==============================] - ETA: 0s - loss: 1.1011 - accuracy: 0.5328
# Epoch 00048: val_accuracy did not improve from 0.41391
# 36/36 [==============================] - 6s 160ms/step - loss: 1.1011 - accuracy: 0.5328 - val_loss: 1.3860 - val_accuracy: 0.3983
# Epoch 49/100
# 36/36 [==============================] - ETA: 0s - loss: 1.0989 - accuracy: 0.5458
# Epoch 00049: val_accuracy did not improve from 0.41391
# 36/36 [==============================] - 6s 161ms/step - loss: 1.0989 - accuracy: 0.5458 - val_loss: 1.3903 - val_accuracy: 0.3965
# Epoch 50/100
# 36/36 [==============================] - ETA: 0s - loss: 1.1030 - accuracy: 0.5406
# Epoch 00050: val_accuracy did not improve from 0.41391
# 36/36 [==============================] - 6s 159ms/step - loss: 1.1030 - accuracy: 0.5406 - val_loss: 1.3868 - val_accuracy: 0.3878
# Epoch 51/100
# 36/36 [==============================] - ETA: 0s - loss: 1.0988 - accuracy: 0.5406
# Epoch 00051: val_accuracy did not improve from 0.41391
# 36/36 [==============================] - 6s 160ms/step - loss: 1.0988 - accuracy: 0.5406 - val_loss: 1.3890 - val_accuracy: 0.3965
# Epoch 52/100
# 36/36 [==============================] - ETA: 0s - loss: 1.0969 - accuracy: 0.5380
# Epoch 00052: val_accuracy did not improve from 0.41391
# 36/36 [==============================] - 6s 159ms/step - loss: 1.0969 - accuracy: 0.5380 - val_loss: 1.3876 - val_accuracy: 0.3930
# Epoch 53/100
# 36/36 [==============================] - ETA: 0s - loss: 1.0928 - accuracy: 0.5580
# Epoch 00053: val_accuracy did not improve from 0.41391
# 36/36 [==============================] - 6s 159ms/step - loss: 1.0928 - accuracy: 0.5580 - val_loss: 1.3904 - val_accuracy: 0.3913
# Epoch 54/100
# 36/36 [==============================] - ETA: 0s - loss: 1.0892 - accuracy: 0.5493
# Epoch 00054: val_accuracy did not improve from 0.41391
# 36/36 [==============================] - 6s 159ms/step - loss: 1.0892 - accuracy: 0.5493 - val_loss: 1.3953 - val_accuracy: 0.3913
# Epoch 55/100
# 36/36 [==============================] - ETA: 0s - loss: 1.0943 - accuracy: 0.5450
# Epoch 00055: val_accuracy did not improve from 0.41391
# 36/36 [==============================] - 6s 160ms/step - loss: 1.0943 - accuracy: 0.5450 - val_loss: 1.3897 - val_accuracy: 0.3896
# Epoch 56/100
# 36/36 [==============================] - ETA: 0s - loss: 1.0897 - accuracy: 0.5463
# Epoch 00056: val_accuracy did not improve from 0.41391
# 36/36 [==============================] - 6s 163ms/step - loss: 1.0897 - accuracy: 0.5463 - val_loss: 1.3953 - val_accuracy: 0.4017
# Epoch 57/100
# 36/36 [==============================] - ETA: 0s - loss: 1.0872 - accuracy: 0.5441
# Epoch 00057: val_accuracy did not improve from 0.41391
# 36/36 [==============================] - 6s 159ms/step - loss: 1.0872 - accuracy: 0.5441 - val_loss: 1.3988 - val_accuracy: 0.3913
# Epoch 58/100
# 36/36 [==============================] - ETA: 0s - loss: 1.0861 - accuracy: 0.5498
# Epoch 00058: val_accuracy did not improve from 0.41391
# 36/36 [==============================] - 6s 161ms/step - loss: 1.0861 - accuracy: 0.5498 - val_loss: 1.3986 - val_accuracy: 0.3826
# Epoch 59/100
# 36/36 [==============================] - ETA: 0s - loss: 1.0792 - accuracy: 0.5624
# Epoch 00059: val_accuracy did not improve from 0.41391
# 36/36 [==============================] - 6s 161ms/step - loss: 1.0792 - accuracy: 0.5624 - val_loss: 1.4011 - val_accuracy: 0.3861
# Epoch 60/100
# 36/36 [==============================] - ETA: 0s - loss: 1.0751 - accuracy: 0.5619
# Epoch 00060: val_accuracy did not improve from 0.41391
# 36/36 [==============================] - 6s 159ms/step - loss: 1.0751 - accuracy: 0.5619 - val_loss: 1.4030 - val_accuracy: 0.3896
# Epoch 61/100
# 36/36 [==============================] - ETA: 0s - loss: 1.
100
# 36/36 [==============================] - ETA: 0s - loss: 1.0182 - accuracy: 0.5845
# Epoch 00100: val_accuracy did not improve from 0.41391
# 36/36 [==============================] - 6s 164ms/step - loss: 1.0182 - accuracy: 0.5845 - val_loss: 1.4394 - val_accuracy: 0.3861

# %%
import json,codecs
import numpy as np
def saveHist(path,history):
 
    new_hist = {}
    for key in list(history.history.keys()):
        if type(history.history[key]) == np.ndarray:
            new_hist[key] == history.history[key].tolist()
        elif type(history.history[key]) == list:
           #if  type(history.history[key][0]) == np.float64:
           new_hist[key] = list(map(float, history.history[key]))
 
    #print(new_hist)
    with codecs.open(path, 'w', encoding='utf-8') as f:
        json.dump(new_hist, f, separators=(',', ':'), sort_keys=True, indent=4) 
 
def loadHist(path):
    with codecs.open(path, 'r', encoding='utf-8') as f:
        n = json.loads(f.read())
    return n
 

saveHist('LSTM-ATTENTION-BF-polution.hist',history)
hist=loadHist('LSTM-ATTENTION-BF-polution.hist')

# %%
print(hist)
# Out:
# {'accuracy': [0.38045376539230347, 0.3821989595890045, 0.3917975425720215, 0.38307154178619385, 0.4066317677497864, 0.41623038053512573, 0.4144851565361023, 0.45375218987464905, 0.4328097701072693, 0.4554973840713501, 0.46073299646377563, 0.4624781906604767, 0.4624781906604767, 0.463350772857666, 0.4589877724647522, 0.4773123860359192, 0.46945899724960327, 0.4825479984283447, 0.49738219380378723, 0.4895288050174713, 0.48691099882125854, 0.5087260007858276, 0.5069807767868042, 0.5026177763938904, 0.5200698375701904, 0.5069807767868042, 0.5104712247848511, 0.5034903883934021, 0.511343777179718, 0.5174520015716553, 0.5095986127853394, 0.5087260007858276, 0.5034903883934021, 0.5148342251777649, 0.5130890011787415, 0.5174520015716553, 0.518324613571167, 0.5218150019645691, 0.5139616131782532, 0.529668390750885, 0.5209423899650574, 0.5287958383560181, 0.5148342251777649, 0.5157067775726318, 0.5191972255706787, 0.5052356123924255, 0.5226876139640808, 0.5235602259635925, 0.5235602259635925, 0.5226876139640808, 0.5122163891792297, 0.5191972255706787, 0.5235602259635925, 0.5130890011787415, 0.5218150019645691, 0.5174520015716553, 0.5148342251777649, 0.518324613571167, 0.5017452239990234, 0.518324613571167, 0.5130890011787415, 0.5209423899650574, 0.5218150019645691, 0.5200698375701904, 0.5174520015716553, 0.5244328379631042, 0.536649227142334, 0.5200698375701904, 0.5392670035362244, 0.5383943915367126, 0.5314136147499084, 0.5191972255706787, 0.5349040031433105, 0.5427573919296265, 0.5436300039291382, 0.5340313911437988, 0.5357766151428223, 0.5401396155357361, 0.5427573919296265, 0.529668390750885, 0.5541012287139893, 0.547993004322052, 0.5514833927154541, 0.5558463931083679, 0.5558463931083679, 0.5523560047149658, 0.5514833927154541, 0.5497382283210754, 0.5462478399276733, 0.5383943915367126, 0.5506108403205872, 0.5610820055007935, 0.5610820055007935, 0.5706806182861328, 0.5619546175003052, 0.5445026159286499, 0.5654450058937073, 0.5636998414993286, 0.5654450058937073, 0.5706806182861328], 'loss': [1.4163403511047363, 1.3684054613113403, 1.351518988609314, 1.3619019985198975, 1.3336437940597534, 1.309101939201355, 1.308912754058838, 1.2931954860687256, 1.3109444379806519, 1.2881441116333008, 1.256982684135437, 1.2519876956939697, 1.2261916399002075, 1.2384711503982544, 1.233580470085144, 1.209733247756958, 1.2131659984588623, 1.200758934020996, 1.1761687994003296, 1.1851909160614014, 1.1817032098770142, 1.1491880416870117, 1.1444621086120605, 1.1464804410934448, 1.1437101364135742, 1.1466256380081177, 1.1437435150146484, 1.135918140411377, 1.1406763792037964, 1.1335482597351074, 1.135602593421936, 1.131360411643982, 1.1344789266586304, 1.132428765296936, 1.1322286128997803, 1.1262067556381226, 1.1281298398971558, 1.1295753717422485, 1.122010588645935, 1.1186928749084473, 1.1192222833633423, 1.1209386587142944, 1.1200792789459229, 1.1193863153457642, 1.1216034889221191, 1.1208491325378418, 1.1119569540023804, 1.110398769378662, 1.1090184450149536, 1.1139310598373413, 1.1170603036880493, 1.105833888053894, 1.105581521987915, 1.1059496402740479, 1.1055972576141357, 1.105997920036316, 1.1119463443756104, 1.1325589418411255, 1.131322979927063, 1.1201142072677612, 1.1169296503067017, 1.1070435047149658, 1.1083797216415405, 1.1014940738677979, 1.098188042640686, 1.1022889614105225, 1.1004180908203125, 1.0976438522338867, 1.0840578079223633, 1.0864686965942383, 1.088312029838562, 1.0946522951126099, 1.0853387117385864, 1.086983561515808, 1.0815914869308472, 1.0776513814926147, 1.0696978569030762, 1.0723512172698975, 1.0765384435653687, 1.0769520998001099, 1.063193678855896, 1.0628657341003418, 1.0672366619110107, 1.064733862876892, 1.0646018981933594, 1.060279369354248, 1.0644882917404175, 1.0587425231933594, 1.059089183807373, 1.0549918413162231, 1.051387071609497, 1.0590863227844238, 1.050877332687378, 1.0435584783554077, 1.0457381010055542, 1.0493216514587402, 1.0459924936294556, 1.0502464771270752, 1.0368759632110596, 1.0297677516937256], 'l ...

# %%
import matplotlib.pylab as plt

acc=np.array(hist['accuracy'])
#acc=acc[0:100]
#acc=np.append(acc,[0.7])
plt.plot(acc,'b--')
plt.plot(hist['val_accuracy'],'b',label='DNNC')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.show()
# summarize history for loss
loss=np.array(hist['loss'])
#loss=np.append(loss,[2])
plt.plot(loss,'b--',label='train')
plt.plot(hist['val_loss'],'b',label='test')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from keras.models import load_model
model = load_model('LSTM-ATTENTION-BF-polution.h5')

# %%
from sklearn.metrics import classification_report, confusion_matrix


print('Confusion Matrix')
cm=confusion_matrix(np.argmax(y_test,axis=1), np.argmax(model.predict(X_test),axis=1))
print(cm)
scores = model.evaluate(X_test,y_test, verbose=0)
print("Dados Validação %s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

pred = model.predict(X_test)
predicted = np.argmax(pred, axis=1)
report = classification_report(np.argmax(y_test, axis=1), predicted,digits=4)
print(report)
# Out:
# Confusion Matrix
# [[75 23 12  2  3]
#  [33 63 27 13  6]
#  [15 43 41 29 12]
#  [ 4 22 21 42 19]
#  [ 7 11 15 20 17]]
# Dados Validação accuracy: 41.39%
#               precision    recall  f1-score   support
#
#            0     0.5597    0.6522    0.6024       115
#            1     0.3889    0.4437    0.4145       142
#            2     0.3534    0.2929    0.3203       140
#            3     0.3962    0.3889    0.3925       108
#            4     0.2982    0.2429    0.2677        70
#
#     accuracy                         0.4139       575
#    macro avg     0.3993    0.4041    0.3995       575
# weighted avg     0.4048    0.4139    0.4071       575

# %%
import seaborn as sns

def cm_analysis(y_true, y_pred, labels, ymap=None, figsize=(10,10)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels = [ymap[yi] for yi in labels]
    cm = confusion_matrix(y_true, y_pred)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    plt.savefig("LSTM-polution.pdf")
    plt.show()
    
    
    
cm_analysis(np.argmax(y_test,axis=1),np.argmax(pred,axis=1), labels=["1","2","3","4","5"], ymap=None, figsize=(6,6))
