# %%
import tensorflow as tf
from keras import backend as K
from keras.models import Sequential
from keras.layers.convolutional import Conv2D 
from keras.layers.convolutional import AveragePooling2D
from keras.layers.core import Activation, Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.datasets import mnist
from keras.utils import np_utils
from keras.optimizers import SGD, RMSprop, Adam
import matplotlib.pyplot as plt
from keras.callbacks import TensorBoard
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import ModelCheckpoint
from keras.engine.topology import Layer,InputSpec
from keras.layers import Input
from keras.models import Model

K.set_image_dim_ordering("th")

class CNN:
    @staticmethod
    def build(timeSteps,variables,classes):
        
        inputNet = Input(shape=(1,timeSteps,variables)) 
        
        
        conv1=Conv2D(10, (5,5), padding="same")(inputNet)
        conv1=AveragePooling2D(pool_size=(2, 1), strides=(2, 1))(conv1)
        conv1=Dropout(0.05)(conv1)
        conv2=Conv2D(10,(5,5), padding="same")(conv1)
        conv2=AveragePooling2D(pool_size=(2, 1), strides=(2, 1))(conv2)
        out1=Dropout(0.05)(conv2)
        flat=Flatten()(out1)
        denselayers=Dense(150)(flat)
        denselayers=Activation("relu")(denselayers)
        denselayers=Dropout(0.15)(denselayers)
        denselayers=Dense(50)(denselayers)
        denselayers=Activation("relu")(denselayers)
        denselayers=Dropout(0.15)(denselayers)
        # a softmax classifier
        classificationLayer=Dense(classes)(denselayers)
        classificationLayer=Activation("softmax")(classificationLayer)
        
        model=Model(inputNet,classificationLayer)
        return model
# Out:
# /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/rjpg/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# load data
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split


def non_shuffling_train_test_split(X, y, test_size=0.2):
    i = int((1 - test_size) * X.shape[0]) + 1
    X_train, X_test = np.split(X, [i])
    y_train, y_test = np.split(y, [i])
    return X_train, X_test, y_train, y_test

# load all data
dfin = pd.read_csv('windows-pm2.5-size168-step24-norm.csv',header=None)  #inputs 72 lines per sample
dfout = pd.read_csv('out-class-size168-step24-pm2.5.csv',header=None)  #output classes 

total_inputs,total_output = dfin.values.astype(np.float32),dfout.values.astype(np.int32)

# normalize
scaler = MinMaxScaler(feature_range=(0, 1))
total_inputs = scaler.fit_transform(total_inputs)




# every 72 lines is one input sample
total_inputs = np.reshape(total_inputs, (-1,168,8))
print("############# total shapes #############")
print(total_inputs.shape)
print(total_output.size)

train_inputs, test_inputs, train_output, test_output = non_shuffling_train_test_split(total_inputs, total_output, test_size=0.25)
#train_inputs, test_inputs, train_output, test_output = train_test_split(total_inputs, total_output, test_size=0.20, random_state=42)
print("############# train shapes #############")
print(train_inputs.shape)
print(train_output.shape)

print("############# test shapes #############")
print(test_inputs.shape)
print(test_output.shape)

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import norm
import statsmodels.api as sm
import matplotlib.pyplot as plt
from datetime import datetime
import requests
from io import BytesIO

counts, bins, patches= plt.hist(total_output, bins=5, edgecolor='gray') 
#plt.title("Number of examples per class  (equally distributed) ")
patches[0].set_facecolor('#FFFFFF')
patches[1].set_facecolor('#CCCCCC')
patches[2].set_facecolor('#888888')
patches[3].set_facecolor('#444444')
patches[4].set_facecolor('#000000')




#create legend
from matplotlib.patches import Rectangle
l0 = '#FFFFFF'
l1 = '#CCCCCC'
l2 = '#888888'
l3 = '#444444'
l4 = '#000000'

#Alarm Color
#l0 = '#009a66'
#l1 = '#3566cd'
#l2 = '#fde101'
#l3 = '#ff6500'
#l4 = '#cb0032'

patches[0].set_facecolor(l0)
patches[1].set_facecolor(l1)
patches[2].set_facecolor(l2)
patches[3].set_facecolor(l3)
patches[4].set_facecolor(l4)

handles = [Rectangle((0,0),1,1,color=c,ec="k") for c in [l0,l1,l2,l3,l4]]
labels= ["Level 0","Level 1", "Level 2","Level 3","Level 4"]
plt.legend(handles, labels)

y = [0,1,2,3,4]
#ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%0.01f'))
#plt.xticks(ticker.FormatStrFormatter('%0.1f'))
plt.xticks(y)
plt.savefig('histo-target-co2-classes-number.svg')
plt.show()
# Out:
# ############# total shapes #############
# (1817, 168, 8)
# 1817
# ############# train shapes #############
# (1363, 168, 8)
# (1363, 1)
# ############# test shapes #############
# (454, 168, 8)
# (454, 1)

# %%
IMG_ROWS, IMG_COLS = 168, 8 # input image dimensions
NB_CLASSES = 5  # number of outputs = number of classes

X_train = train_inputs[:, np.newaxis, :, :]
y_train = np_utils.to_categorical(train_output, NB_CLASSES)
X_test = test_inputs[:, np.newaxis, :, :]
y_test = np_utils.to_categorical(test_output, NB_CLASSES)
print(y_test.shape)

OPTIMIZER = Adam()

model = CNN.build(timeSteps=IMG_ROWS,variables=IMG_COLS,classes=NB_CLASSES)
model.compile(loss="categorical_crossentropy", optimizer=OPTIMIZER,
	metrics=["accuracy"])

model.summary()
# Out:
# (454, 5)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 1, 168, 8)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 168, 8)        260
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 10, 84, 8)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 10, 84, 8)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 84, 8)         2510
# _________________________________________________________________
# average_pooling2d_4 (Average (None, 10, 42, 8)         0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 10, 42, 8)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3360)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 150)               504150
# _________________________________________________________________
# activation_4 (Activation)    (None, 150)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 150)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                7550
# _________________________________________________________________
# activation_5 (Activation)    (None, 50)                0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 255
# _________________________________________________________________
# activation_6 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 514,725
# Trainable params: 514,725
# Non-trainable params: 0
# _________________________________________________________________

# %%
from IPython.display import SVG,display
from keras.utils.vis_utils import model_to_dot
modelSVG=SVG(model_to_dot(model,show_shapes=True).create(prog='dot', format='svg'))
display(modelSVG)

# %%
NB_EPOCH = 100
BATCH_SIZE = 64
VERBOSE = 1

#tbCallBack = TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True)
#esCallBack = EarlyStopping(monitor='val_acc', min_delta=0, patience=12, verbose=0, mode='max')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.01,patience=5, min_lr=0.0001)
best_checkpoint = ModelCheckpoint('CNN-polution.h5', monitor='val_acc', save_best_only=True, verbose=1)

history = model.fit(X_train, y_train, 
		batch_size=BATCH_SIZE, epochs=NB_EPOCH, 
		verbose=1, # 0 for no logging to stdout, 1 for progress bar logging, 2 for one log line per epoch.
		validation_data=(X_test,y_test),
		#validation_split=VALIDATION_SPLIT,
		callbacks=[reduce_lr,best_checkpoint])
# Out:
# Train on 1363 samples, validate on 454 samples
# Epoch 1/100
# 1363/1363 [==============================] - 7s 5ms/step - loss: 1.6267 - acc: 0.2157 - val_loss: 1.5867 - val_acc: 0.2643
#
# Epoch 00001: val_acc improved from -inf to 0.26432, saving model to CNN-polution.h5
# Epoch 2/100
# 1363/1363 [==============================] - 0s 142us/step - loss: 1.5903 - acc: 0.2641 - val_loss: 1.5725 - val_acc: 0.2974
#
# Epoch 00002: val_acc improved from 0.26432 to 0.29736, saving model to CNN-polution.h5
# Epoch 3/100
# 1363/1363 [==============================] - 0s 142us/step - loss: 1.5505 - acc: 0.2920 - val_loss: 1.5618 - val_acc: 0.2775
#
# Epoch 00003: val_acc did not improve from 0.29736
# Epoch 4/100
# 1363/1363 [==============================] - 0s 147us/step - loss: 1.4869 - acc: 0.3492 - val_loss: 1.4267 - val_acc: 0.3921
#
# Epoch 00004: val_acc improved from 0.29736 to 0.39207, saving model to CNN-polution.h5
# Epoch 5/100
# 1363/1363 [==============================] - 0s 148us/step - loss: 1.4511 - acc: 0.3522 - val_loss: 1.4345 - val_acc: 0.3811
#
# Epoch 00005: val_acc did not improve from 0.39207
# Epoch 6/100
# 1363/1363 [==============================] - 0s 149us/step - loss: 1.4121 - acc: 0.3786 - val_loss: 1.4519 - val_acc: 0.3656
#
# Epoch 00006: val_acc did not improve from 0.39207
# Epoch 7/100
# 1363/1363 [==============================] - 0s 152us/step - loss: 1.3695 - acc: 0.4233 - val_loss: 1.4054 - val_acc: 0.3855
#
# Epoch 00007: val_acc did not improve from 0.39207
# Epoch 8/100
# 1363/1363 [==============================] - 0s 151us/step - loss: 1.3667 - acc: 0.4094 - val_loss: 1.3822 - val_acc: 0.3965
#
# Epoch 00008: val_acc improved from 0.39207 to 0.39648, saving model to CNN-polution.h5
# Epoch 9/100
# 1363/1363 [==============================] - 0s 148us/step - loss: 1.3329 - acc: 0.4204 - val_loss: 1.4788 - val_acc: 0.3722
#
# Epoch 00009: val_acc did not improve from 0.39648
# Epoch 10/100
# 1363/1363 [==============================] - 0s 150us/step - loss: 1.3194 - acc: 0.4512 - val_loss: 1.3753 - val_acc: 0.3987
#
# Epoch 00010: val_acc improved from 0.39648 to 0.39868, saving model to CNN-polution.h5
# Epoch 11/100
# 1363/1363 [==============================] - 0s 146us/step - loss: 1.2721 - acc: 0.4710 - val_loss: 1.4332 - val_acc: 0.3634
#
# Epoch 00011: val_acc did not improve from 0.39868
# Epoch 12/100
# 1363/1363 [==============================] - 0s 153us/step - loss: 1.2632 - acc: 0.4534 - val_loss: 1.4025 - val_acc: 0.3833
#
# Epoch 00012: val_acc did not improve from 0.39868
# Epoch 13/100
# 1363/1363 [==============================] - 0s 157us/step - loss: 1.2091 - acc: 0.5070 - val_loss: 1.4188 - val_acc: 0.3877
#
# Epoch 00013: val_acc did not improve from 0.39868
# Epoch 14/100
# 1363/1363 [==============================] - 0s 145us/step - loss: 1.1825 - acc: 0.5077 - val_loss: 1.4180 - val_acc: 0.3987
#
# Epoch 00014: val_acc did not improve from 0.39868
# Epoch 15/100
# 1363/1363 [==============================] - 0s 151us/step - loss: 1.1618 - acc: 0.5099 - val_loss: 1.4536 - val_acc: 0.3899
#
# Epoch 00015: val_acc did not improve from 0.39868
# Epoch 16/100
# 1363/1363 [==============================] - 0s 145us/step - loss: 1.0875 - acc: 0.5510 - val_loss: 1.4834 - val_acc: 0.3656
#
# Epoch 00016: val_acc did not improve from 0.39868
# Epoch 17/100
# 1363/1363 [==============================] - 0s 150us/step - loss: 1.0684 - acc: 0.5605 - val_loss: 1.4874 - val_acc: 0.3744
#
# Epoch 00017: val_acc did not improve from 0.39868
# Epoch 18/100
# 1363/1363 [==============================] - 0s 152us/step - loss: 1.0640 - acc: 0.5510 - val_loss: 1.4811 - val_acc: 0.3811
#
# Epoch 00018: val_acc did not improve from 0.39868
# Epoch 19/100
# 1363/1363 [==============================] - 0s 155us/step - loss: 1.0618 - acc: 0.5752 - val_loss: 1.4888 - val_acc: 0.3855
#
# Epoch 00019: val_acc did not improve from 0.39868
# Epoch 20/100
# 1363/1363 [==============================] - 0s 144us/step - loss: 1.0169 - acc: 0.5818 - val_loss: 1.4875 - val_acc: 0.3855
#
# Epoch 00020: val_acc did not improve from 0.39868
# Epoch 21/100
# 1363/1363 [==============================] - 0s 155us/step - loss: 1.0113 - acc: 0.5950 - val_loss: 1.5071 - val_acc: 0.3700
#
# Epoch 00021: val_acc did not improve from 0.39868
# Epoch 22/100
# 1363/1363 [==============================] - 0s 155us/step - loss: 1.0041 - acc: 0.6016 - val_loss: 1.5017 - val_acc: 0.3656
#
# Epoch 00022: val_acc did not improve from 0.39868
# Epoch 23/100
# 1363/1363 [==============================] - 0s 152us/step - loss: 0.9986 - acc: 0.6038 - val_loss: 1.5213 - val_acc: 0.3722
#
# Epoch 00023: val_acc did not improve from 0.39868
# Epoch 24/100
# 1363/1363 [==============================] - 0s 159us/step - loss: 0.9956 - acc: 0.5965 - val_loss: 1.5248 - val_acc: 0.3678
#
# Epoch 00024: val_acc did not improve from 0.39868
# Epoch 25/100
# 1363/1363 [==============================] - 0s 146us/step - loss: 1.0011 - acc: 0.5987 - val_loss: 1.5166 - val_acc: 0.3722
#
# Epoch 00025: val_acc did not improve from 0.39868
# Epoch 26/100
# 1363/1363 [==============================] - 0s 152us/step - loss: 1.0037 - acc: 0.5979 - val_loss: 1.5238 - val_acc: 0.3789
#
# Epoch 00026: val_acc did not improve from 0.39868
# Epoch 27/100
# 1363/1363 [==============================] - 0s 151us/step - loss: 0.9715 - acc: 0.6126 - val_loss: 1.5182 - val_acc: 0.3789
#
# Epoch 00027: val_acc did not improve from 0.39868
# Epoch 28/100
# 1363/1363 [==============================] - 0s 154us/step - loss: 0.9876 - acc: 0.6045 - val_loss: 1.5256 - val_acc: 0.3811
#
# Epoch 00028: val_acc did not improve from 0.39868
# Epoch 29/100
# 1363/1363 [==============================] - 0s 152us/step - loss: 0.9667 - acc: 0.6207 - val_loss: 1.5112 - val_acc: 0.3811
#
# Epoch 00029: val_acc did not improve from 0.39868
# Epoch 30/100
# 1363/1363 [==============================] - 0s 150us/step - loss: 0.9586 - acc: 0.6236 - val_loss: 1.5382 - val_acc: 0.3722
#
# Epoch 00030: val_acc did not improve from 0.39868
# Epoch 31/100
# 1363/1363 [==============================] - 0s 153us/step - loss: 0.9448 - acc: 0.6170 - val_loss: 1.5354 - val_acc: 0.3789
#
# Epoch 00031: val_acc did not improve from 0.39868
# Epoch 32/100
# 1363/1363 [==============================] - 0s 152us/step - loss: 0.9441 - acc: 0.6214 - val_loss: 1.5546 - val_acc: 0.3789
#
# Epoch 00032: val_acc did not improve from 0.39868
# Epoch 33/100
# 1363/1363 [==============================] - 0s 152us/step - loss: 0.9333 - acc: 0.6288 - val_loss: 1.5500 - val_acc: 0.3789
#
# Epoch 00033: val_acc did not improve from 0.39868
# Epoch 34/100
# 1363/1363 [==============================] - 0s 151us/step - loss: 0.9426 - acc: 0.6266 - val_loss: 1.5494 - val_acc: 0.3767
#
# Epoch 00034: val_acc did not improve from 0.39868
# Epoch 35/100
# 1363/1363 [==============================] - 0s 151us/step - loss: 0.9182 - acc: 0.6346 - val_loss: 1.5540 - val_acc: 0.3722
#
# Epoch 00035: val_acc did not improve from 0.39868
# Epoch 36/100
# 1363/1363 [==============================] - 0s 155us/step - loss: 0.9188 - acc: 0.6390 - val_loss: 1.5642 - val_acc: 0.3789
#
# Epoch 00036: val_acc did not improve from 0.39868
# Epoch 37/100
# 1363/1363 [==============================] - 0s 153us/step - loss: 0.9096 - acc: 0.6390 - val_loss: 1.5636 - val_acc: 0.3656
#
# Epoch 00037: val_acc did not improve from 0.39868
# Epoch 38/100
# 1363/1363 [==============================] - 0s 153us/step - loss: 0.8928 - acc: 0.6544 - val_loss: 1.5870 - val_acc: 0.3678
#
# Epoch 00038: val_acc did not improve from 0.39868
# Epoch 39/100
# 1363/1363 [==============================] - 0s 154us/step - loss: 0.9040 - acc: 0.6442 - val_loss: 1.5819 - val_acc: 0.3877
#
# Epoch 00039: val_acc did not improve from 0.39868
# Epoch 40/100
# 1363/1363 [==============================] - 0s 153us/step - loss: 0.8844 - acc: 0.6368 - val_loss: 1.5875 - val_acc: 0.3744
#
# Epoch 00040: val_acc did not improve from 0.39868
# Epoch 41/100
# 1363/1363 [==============================] - 0s 148us/step - loss: 0.8853 - acc: 0.6596 - val_loss: 1.5860 - val_acc: 0.3833
#
# Epoch 00041: val_acc did not improve from 0.39868
# Epoch 42/100
# 1363/1363 [==============================] - 0s 158us/step - loss: 0.8974 - acc: 0.6515 - val_loss: 1.5860 - val_acc: 0.3811
#
# Epoch 00042: val_acc did not improve from 0.39868
# Epoch 43/100
# 1363/1363 [==============================] - 0s 150us/step - loss: 0.8609 - acc: 0.6764 - val_loss: 1.5964 - val_acc: 0.3833
#
# Epoch 00043: val_acc did not improve from 0.39868
# Epoch 44/100
# 1363/1363 [==============================] - 0s 151us/step - loss: 0.8670 - acc: 0.6779 - val_loss: 1.5905 - val_acc: 0.3965
#
# Epoch 00044: val_acc did not improve from 0.39868
# Epoch 45/100
# 1363/1363 [==============================] - 0s 149us/step - loss: 0.8569 - acc: 0.6691 - val_loss: 1.5883 - val_acc: 0.3921
#
# Epoch 00045: val_acc did not improve from 0.39868
# Epoch 46/100
# 1363/1363 [==============================] - 0s 153us/step - loss: 0.8441 - acc: 0.6640 - val_loss: 1.5997 - val_acc: 0.3899
#
# Epoch 00046: val_acc did not improve from 0.39868
# Epoch 47/100
# 1363/1363 [==============================] - 0s 144us/step - loss: 0.8421 - acc: 0.6764 - val_loss: 1.6096 - val_acc: 0.3811
#
# Epoch 00047: val_acc did not improve from 0.39868
# Epoch 48/100
# 1363/1363 [==============================] - 0s 145us/step - loss: 0.8294 - acc: 0.6742 - val_loss: 1.6147 - val_acc: 0.3833
#
# Epoch 00048: val_acc did not improve from 0.39868
# Epoch 49/100
# 1363/1363 [==============================] - 0s 158us/step - loss: 0.8156 - acc: 0.6801 - val_loss: 1.6344 - val_acc: 0.3811
#
# Epoch 00049: val_acc did not improve from 0.39868
# Epoch 50/100
# 1363/1363 [==============================] - 0s 151us/step - loss: 0.8074 - acc: 0.6963 - val_loss: 1.6266 - val_acc: 0.3833
#
# Epoch 00050: val_acc did not improve from 0.39868
# Epoch 51/100
# 1363/1363 [==============================] - 0s 147us/step - loss: 0.8074 - acc: 0.6911 - val_loss: 1.6428 - val_acc: 0.3789
#
# Epoch 00051: val_acc did not improve from 0.39868
# Epoch 52/100
# 1363/1363 [==============================] - 0s 159us/step - loss: 0.8024 - acc: 0.6992 - val_loss: 1.6183 - val_acc: 0.3811
#
# Epoch 00052: val_acc did not improve from 0.39868
# Epoch 53/100
# 1363/1363 [==============================] - 0s 151us/step - loss: 0.7975 - acc: 0.6992 - val_loss: 1.6425 - val_acc: 0.3811
#
# Epoch 00053: val_acc did not improve from 0.39868
# Epoch 54/100
# 1363/1363 [==============================] - 0s 153us/step - loss: 0.7986 - acc: 0.6926 - val_loss: 1.6527 - val_acc: 0.3767
#
# Epoch 00054: val_acc did not improve from 0.39868
# Epoch 55/100
# 1363/1363 [==============================] - 0s 151us/step - loss: 0.7753 - acc: 0.7190 - val_loss: 1.6778 - val_acc: 0.3877
#
# Epoch 00055: val_acc did not improve from 0.39868
# Epoch 56/100
# 1363/1363 [==============================] - 0s 160us/step - loss: 0.7817 - acc: 0.7102 - val_loss: 1.6488 - val_acc: 0.3744
#
# Epoch 00056: val_acc did not improve from 0.39868
# Epoch 57/100
# 1363/1363 [==============================] - 0s 153us/step - loss: 0.7587 - acc: 0.7117 - val_loss: 1.6638 - val_acc: 0.3722
#
# Epoch 00057: val_acc did not improve from 0.39868
# Epoch 58/100
# 1363/1363 [==============================] - 0s 143us/step - loss: 0.7570 - acc: 0.7087 - val_loss: 1.6836 - val_acc: 0.3877
#
# Epoch 00058: val_acc did not improve from 0.39868
# Epoch 59/100
# 1363/1363 [==============================] - 0s 155us/step - loss: 0.7675 - acc: 0.6992 - val_loss: 1.6687 - val_acc: 0.3855
#
# Epoch 00059: val_acc did not improve from 0.39868
# Epoch 60/100
# 1363/1363 [==============================] - 0s 153us/step - loss: 0.7371 - acc: 0.7285 - val_loss: 1.6938 - val_acc: 0.3767
#
# Epoch 00060: val_acc did not improve from 0.39868
# Epoch 61/100
# 1363/1363 [==============================] - 0s 149us/step - loss: 0.7338 - acc: 0.7285 - val_loss: 1.6817 - val_acc: 0.3767
#
# Epoch 00061: val_acc did not improve from 0.39868
# Epoch 62/100
# 1363/1363 [==============================] - 0s 157us/step - loss: 0.7227 - acc: 0.7344 - val_loss: 1.7023 - val_acc: 0.3833
#
# Epoch 00062: val_acc did not improve from 0.39868
# Epoch 63/100
# 1363/1363 [==============================] - 0s 154us/step - loss: 0.7252 - acc: 0.7351 - val_loss: 1.6933 - val_acc: 0.3855
#
# Epoch 00063: val_acc did not improve from 0.39868
# Epoch 64/100
# 1363/1363 [==============================] - 0s 150us/step - loss: 0.6956 - acc: 0.7557 - val_loss: 1.7231 - val_acc: 0.3877
#
# Epoch 00064: val_acc did not improve from 0.39868
# Epoch 65/100
# 1363/1363 [==============================] - 0s 154us/step - loss: 0.7171 - acc: 0.7410 - val_loss: 1.7160 - val_acc: 0.3855
#
# Epoch 00065: val_acc did not improve from 0.39868
# Epoch 66/100
# 1363/1363 [==============================] - 0s 157us/step - loss: 0.7115 - acc: 0.7395 - val_loss: 1.7117 - val_acc: 0.3811
#
# Epoch 00066: val_acc did not improve from 0.39868
# Epoch 67/100
# 1363/1363 [==============================] - 0s 153us/step - loss: 0.6943 - acc: 0.7476 - val_loss: 1.7601 - val_acc: 0.3877
#
# Epoch 00067: val_acc did not improve from 0.39868
# Epoch 68/100
# 1363/1363 [==============================] - 0s 152us/step - loss: 0.7049 - acc: 0.7351 - val_loss: 1.6989 - val_acc: 0.3833
#
# Epoch 00068: val_acc did not improve from 0.39868
# Epoch 69/100
# 1363/1363 [==============================] - 0s 153us/step - loss: 0.6705 - acc: 0.7586 - val_loss: 1.7354 - val_acc: 0.3811
#
# Epoch 00069: val_acc did not improve from 0.39868
# Epoch 70/100
# 1363/1363 [==============================] - 0s 152us/step - loss: 0.6853 - acc: 0.7520 - val_loss: 1.7189 - val_acc: 0.3855
#
# Epoch 00070: val_acc did not improve from 0.39868
# Epoch 71/100
# 1363/1363 [==============================] - 0s 153us/step - loss: 0.6686 - acc: 0.7432 - val_loss: 1.7613 - val_acc: 0.3855
#
# Epoch 00071: val_acc did not improve from 0.39868
# Epoch 72/100
# 1363/1363 [==============================] - 0s 155us/step - loss: 0.6652 - acc: 0.7572 - val_loss: 1.7499 - val_acc: 0.3899
#
# Epoch 00072: val_acc did not improve from 0.39868
# Epoch 73/100
# 1363/1363 [==============================] - 0s 144us/step - loss: 0.6559 - acc: 0.7696 - val_loss: 1.7535 - val_acc: 0.3921
#
# Epoch 00073: val_acc did not improve from 0.39868
# Epoch 74/100
# 1363/1363 [==============================] - 0s 154us/step - loss: 0.6474 - acc: 0.7498 - val_loss: 1.7449 - val_acc: 0.4031
#
# Epoch 00074: val_acc improved from 0.39868 to 0.40308, saving model to CNN-polution.h5
# Epoch 75/100
# 1363/1363 [==============================] - 0s 147us/step - loss: 0.6333 - acc: 0.7784 - val_loss: 1.8087 - val_acc: 0.3877
#
# Epoch 00075: val_acc did not improve from 0.40308
# Epoch 76/100
# 1363/1363 [==============================] - 0s 154us/step - loss: 0.6414 - acc: 0.7601 - val_loss: 1.8098 - val_acc: 0.3811
#
# Epoch 00076: val_acc did not improve from 0.40308
# Epoch 77/100
# 1363/1363 [==============================] - 0s 151us/step - loss: 0.6055 - acc: 0.7968 - val_loss: 1.8392 - val_acc: 0.3722
#
# Epoch 00077: val_acc did not improve from 0.40308
# Epoch 78/100
# 1363/1363 [==============================] - 0s 149us/step - loss: 0.6478 - acc: 0.7476 - val_loss: 1.8038 - val_acc: 0.3987
#
# Epoch 00078: val_acc did not improve from 0.40308
# Epoch 79/100
# 1363/1363 [==============================] - 0s 144us/step - loss: 0.6240 - acc: 0.7718 - val_loss: 1.8236 - val_acc: 0.3767
#
# Epoch 00079: val_acc did not improve from 0.40308
# Epoch 80/100
# 1363/1363 [==============================] - 0s 145us/step - loss: 0.6077 - acc: 0.7784 - val_loss: 1.8348 - val_acc: 0.3921
#
# Epoch 00080: val_acc did not improve from 0.40308
# Epoch 81/100
# 1363/1363 [==============================] - 0s 148us/step - loss: 0.5794 - acc: 0.7887 - val_loss: 1.8228 - val_acc: 0.3877
#
# Epoch 00081: val_acc did not improve from 0.40308
# Epoch 82/100
# 1363/1363 [==============================] - 0s 147us/step - loss: 0.5934 - acc: 0.7792 - val_loss: 1.8402 - val_acc: 0.3767
#
# Epoch 00082: val_acc did not improve from 0.40308
# Epoch 83/100
# 1363/1363 [==============================] - 0s 147us/step - loss: 0.5874 - acc: 0.7894 - val_loss: 1.8507 - val_acc: 0.3899
#
# Epoch 00083: val_acc did not improve from 0.40308
# Epoch 84/100
# 1363/1363 [==============================] - 0s 154us/step - loss: 0.5786 - acc: 0.7916 - val_loss: 1.8559 - val_acc: 0.3789
#
# Epoch 00084: val_acc did not improve from 0.40308
# Epoch 85/100
# 1363/1363 [==============================] - 0s 158us/step - loss: 0.5580 - acc: 0.7931 - val_loss: 1.8318 - val_acc: 0.3943
#
# Epoch 00085: val_acc did not improve from 0.40308
# Epoch 86/100
# 1363/1363 [==============================] - 0s 170us/step - loss: 0.5694 - acc: 0.7887 - val_loss: 1.8644 - val_acc: 0.3921
#
# Epoch 00086: val_acc did not improve from 0.40308
# Epoch 87/100
# 1363/1363 [==============================] - 0s 160us/step - loss: 0.5519 - acc: 0.8092 - val_loss: 1.8759 - val_acc: 0.3833
#
# Epoch 00087: val_acc did not improve from 0.40308
# Epoch 88/100
# 1363/1363 [==============================] - 0s 163us/step - loss: 0.5502 - acc: 0.8107 - val_loss: 1.9065 - val_acc: 0.3833
#
# Epoch 00088: val_acc did not improve from 0.40308
# Epoch 89/100
# 1363/1363 [==============================] - 0s 202us/step - loss: 0.5438 - acc: 0.8210 - val_loss: 1.8934 - val_acc: 0.3877
#
# Epoch 00089: val_acc did not improve from 0.40308
# Epoch 90/100
# 1363/1363 [==============================] - 0s 218us/step - loss: 0.5358 - acc: 0.8136 - val_loss: 1.8931 - val_acc: 0.3811
#
# Epoch 00090: val_acc did not improve from 0.40308
# Epoch 91/100
# 1363/1363 [==============================] - 0s 266us/step - loss: 0.5274 - acc: 0.8085 - val_loss: 1.9348 - val_acc: 0.3700
#
# Epoch 00091: val_acc did not improve from 0.40308
# Epoch 92/100
# 1363/1363 [==============================] - 0s 233us/step - loss: 0.5376 - acc: 0.8100 - val_loss: 1.8897 - val_acc: 0.3833
#
# Epoch 00092: val_acc did not improve from 0.40308
# Epoch 93/100
# 1363/1363 [==============================] - 0s 239us/step - loss: 0.5180 - acc: 0.8056 - val_loss: 1.9065 - val_acc: 0.3833
#
# Epoch 00093: val_acc did not improve from 0.40308
# Epoch 94/100
# 1363/1363 [==============================] - 0s 228us/step - loss: 0.5068 - acc: 0.8247 - val_loss: 1.9357 - val_acc: 0.3899
#
# Epoch 00094: val_acc did not improve from 0.40308
# Epoch 95/100
# 1363/1363 [==============================] - 0s 160us/step - loss: 0.5121 - acc: 0.8114 - val_loss: 1.9698 - val_acc: 0.3855
#
# Epoch 00095: val_acc did not improve from 0.40308
# Epoch 96/100
# 1363/1363 [==============================] - 0s 160us/step - loss: 0.5093 - acc: 0.8269 - val_loss: 1.9645 - val_acc: 0.3700
#
# Epoch 00096: val_acc did not improve from 0.40308
# Epoch 97/100
# 1363/1363 [==============================] - 0s 157us/step - loss: 0.4978 - acc: 0.8247 - val_loss: 1.9597 - val_acc: 0.3789
#
# Epoch 00097: val_acc did not improve from 0.40308
# Epoch 98/100
# 1363/1363 [==============================] - 0s 151us/step - loss: 0.4813 - acc: 0.8379 - val_loss: 1.9749 - val_acc: 0.3877
#
# Epoch 00098: val_acc did not improve from 0.40308
# Epoch 99/100
# 1363/1363 [==============================] - 0s 143us/step - loss: 0.4852 - acc: 0.8225 - val_loss: 1.9681 - val_acc: 0.3899
#
# Epoch 00099: val_acc did not improve from 0.40308
# Epoch 100/100
# 1363/1363 [==============================] - 0s 163us/step - loss: 0.4774 - acc: 0.8239 - val_loss: 2.0004 - val_acc: 0.3789
#
# Epoch 00100: val_acc did not improve from 0.40308

# %%
import json,codecs
import numpy as np
def saveHist(path,history):

    new_hist = {}
    for key in list(history.history.keys()):
        if type(history.history[key]) == np.ndarray:
            new_hist[key] == history.history[key].tolist()
        elif type(history.history[key]) == list:
           if  type(history.history[key][0]) == np.float64:
               new_hist[key] = list(map(float, history.history[key]))

    #print(new_hist)
    with codecs.open(path, 'w', encoding='utf-8') as f:
        json.dump(new_hist, f, separators=(',', ':'), sort_keys=True, indent=4) 

def loadHist(path):
    with codecs.open(path, 'r', encoding='utf-8') as f:
        n = json.loads(f.read())
    return n


saveHist('CNN-polution.hist',history)
hist=loadHist('CNN-polution.hist')

# %%
import matplotlib.pylab as plt

acc=np.array(hist['acc'])
#acc=acc[0:100]
#acc=np.append(acc,[0.7])
plt.plot(acc,'b--')
plt.plot(hist['val_acc'],'b',label='DNNC')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.show()
# summarize history for loss
loss=np.array(hist['loss'])
#loss=np.append(loss,[2])
plt.plot(loss,'b--',label='train')
plt.plot(hist['val_loss'],'b',label='test')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
