# %%
import tensorflow as tf
from keras import backend as K
from keras.models import Sequential
from keras.layers.convolutional import Conv2D, Conv3D
from keras.layers.convolutional import AveragePooling2D
from keras.layers.core import Activation, Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.datasets import mnist
from keras.utils import np_utils
from keras.optimizers import SGD, RMSprop, Adam
import matplotlib.pyplot as plt
from keras.callbacks import TensorBoard
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import ModelCheckpoint
from keras.engine.topology import Layer,InputSpec
from keras.layers import ConvLSTM2D
from keras.layers import Input, Permute,  Reshape,  Lambda, Concatenate
from keras.layers.merge import concatenate
from keras.models import Model
from keras.layers.wrappers import Bidirectional, TimeDistributed
from keras.layers import merge, Multiply

K.image_data_format()
K.set_image_data_format('channels_first')



K.image_data_format()
K.set_image_data_format('channels_first')
#tf.config.experimental.list_physical_devices('GPU')
tf.config.list_physical_devices('GPU')
tf.test.is_gpu_available()

print("tf.__version__ is", tf.__version__)
print("tf.keras.__version__ is:", tf.keras.__version__)

def _get_available_gpus():
    """Get a list of available gpu devices (formatted as strings).

    # Returns
        A list of available GPU devices.
    """
    #global _LOCAL_DEVICES
    if tfback._LOCAL_DEVICES is None:
        devices = tf.config.list_logical_devices()
        tfback._LOCAL_DEVICES = [x.name for x in devices]
    return [x for x in tfback._LOCAL_DEVICES if 'device:gpu' in x.lower()]

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))


class CylindricalPadLSTMCNN(Layer):

    def __init__(self, m=0,n=1, **kwargs):
        super(CylindricalPadLSTMCNN, self).__init__(**kwargs)
        self.n = n
        self.m = m
        assert n > 0, 'n must be positive'
        
    def build(self, input_shape):
        self.input_spec = [InputSpec(shape=input_shape)]
        super(CylindricalPadLSTMCNN, self).build(input_shape)  
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0],
                input_shape[1],
                    input_shape[2],
                    input_shape[3] + 2*self.m,
                    input_shape[4] + 2*self.n)

    def get_output_shape_for(self, input_shape):
        return (input_shape[0],
                input_shape[1],
                    input_shape[2],
                    input_shape[3] + 2*self.m,
                    input_shape[4] + 2*self.n)
    
    def call(self,testElement, mask=None):
        firstColumns=testElement[:,:,:,:,0:self.n]
        lastColumns=testElement[:,:,:,:,testElement.shape[4]-self.n:testElement.shape[4]]
        result=tf.concat([testElement,firstColumns], axis=4)
        result=tf.concat([lastColumns,result], axis=4)
        if self.m != 0 :
            #x = tf.placeholder(result.dtype, shape=[result.shape[0],result.shape[1],self.m,result.shape[3]])
            #y = tf.zeros_like(x,dtype=result.dtype)
            
            firstRows=result[:,:,:,0:self.m,:]
            
            y = tf.fill(tf.shape(firstRows), 0.)
            
            #y=tf.fill([result.shape[0],result.shape[1],self.m,result.shape[3]],0.)
            
            #y = tf.constant(0., shape=[result.shape[0],result.shape[1],self.m,result.shape[3]],dtype=result.dtype)
            result=tf.concat([y,result], axis=3)
            result=tf.concat([result,y], axis=3)
        
        return result

    def get_config(self):
        config = {'n': self.n,
        'm': self.m}
        base_config = super(CylindricalPadLSTMCNN, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

class CylindricalPad(Layer):

    def __init__(self, m=0,n=1, **kwargs):
        super(CylindricalPad, self).__init__(**kwargs)
        self.n = n
        self.m = m
        #assert n > 0, 'n must be positive'
        
    def build(self, input_shape):
        self.input_spec = [InputSpec(shape=input_shape)]
        super(CylindricalPad, self).build(input_shape)  
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0],
                    input_shape[1],
                    #input_shape[2] + self.m,
                    # ONLY ADD m 0's to the left for casusal padding
                    input_shape[2] + 2*self.m,
                    input_shape[3] + 2*self.n)

    def get_output_shape_for(self, input_shape):
        return (input_shape[0],
                    input_shape[1],
                    #input_shape[2] + self.m,
                    # ONLY ADD m 0's to the left for casusal padding
                    input_shape[2] + 2*self.m,
                    input_shape[3] + 2*self.n)
    
    def call(self,testElement, mask=None):
        #print(testElement.shape)
        firstColumns=testElement[:,:,:,0:self.n]
        lastColumns=testElement[:,:,:,testElement.shape[3]-self.n:testElement.shape[3]]
        result=tf.concat([testElement,firstColumns], axis=3)
        result=tf.concat([lastColumns,result], axis=3)
        if self.m != 0 :
          firstRows=result[:,:,0:self.m,:]
          y = tf.fill(tf.shape(firstRows), 0.)
          result=tf.concat([y,result], axis=2)
          result=tf.concat([result,y], axis=2)
          
        return result

    def get_config(self):
        config = {'n': self.n,
        'm': self.m}
        base_config = super(CylindricalPad, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

class CylindricalPadCausal(Layer):

    def __init__(self, m=0,n=1, **kwargs):
        super(CylindricalPadCausal, self).__init__(**kwargs)
        self.n = n
        self.m = m
        #assert n > 0, 'n must be positive'
        
    def build(self, input_shape):
        self.input_spec = [InputSpec(shape=input_shape)]
        super(CylindricalPadCausal, self).build(input_shape)  
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0],
                    input_shape[1],
                    #input_shape[2] + 2*self.m,
                    # ONLY ADD m 0's to the left for casusal padding
                    input_shape[2] + self.m,
                    input_shape[3] + 2*self.n)

    def get_output_shape_for(self, input_shape):
        return (input_shape[0],
                    input_shape[1],
                    #input_shape[2] + 2*self.m,
                    # ONLY ADD m 0's to the left for casusal padding
                    input_shape[2] + self.m,
                    input_shape[3] + 2*self.n)
    
    def call(self,testElement, mask=None):
        firstColumns=testElement[:,:,:,0:self.n]
        lastColumns=testElement[:,:,:,testElement.shape[3]-self.n:testElement.shape[3]]
        result=tf.concat([testElement,firstColumns], axis=3)
        result=tf.concat([lastColumns,result], axis=3)
        if self.m != 0 :
            #x = tf.placeholder(result.dtype, shape=[result.shape[0],result.shape[1],self.m,result.shape[3]])
            #y = tf.zeros_like(x,dtype=result.dtype)
            
            firstRows=result[:,:,0:self.m,:]
            
            #y = tf.fill(tf.shape(firstRows), 0.)
            sa=tf.shape(firstRows)[0]
            sb=tf.shape(firstRows)[1]
            sc=self.m
            sd=tf.shape(firstRows)[3]
            y = tf.fill([sa, sb,sc, sd], 0.)
            
            #y=tf.fill([result.shape[0],result.shape[1],self.m,result.shape[3]],0.)
            
            #y = tf.constant(0., shape=[result.shape[0],result.shape[1],self.m,result.shape[3]],dtype=result.dtype)
            result=tf.concat([y,result], axis=2)
            
            ########## only add 0's to de left for casusal pading
            #############result=tf.concat([result,y], axis=2)
        
        return result

    def get_config(self):
        config = {'n': self.n,
        'm': self.m}
        base_config = super(CylindricalPadCausal, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))


class CylindricalNot(Layer):

    def __init__(self, m=0,n=1, **kwargs):
        super(CylindricalNot, self).__init__(**kwargs)
        self.n = n
        self.m = m
        #assert n > 0, 'n must be positive'
        
    def build(self, input_shape):
        self.input_spec = [InputSpec(shape=input_shape)]
        super(CylindricalNot, self).build(input_shape)  
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0],
                    input_shape[1],
                    #input_shape[2] + 2*self.m,
                    # ONLY ADD m 0's to the left for casusal padding
                    input_shape[2] ,
                    input_shape[3] )

    def get_output_shape_for(self, input_shape):
        return (input_shape[0],
                    input_shape[1],
                    #input_shape[2] + 2*self.m,
                    # ONLY ADD m 0's to the left for casusal padding
                    input_shape[2] ,
                    input_shape[3] )
    
    def call(self,testElement, mask=None):
        
        return testElement

    def get_config(self):
        config = {'n': self.n,
        'm': self.m}
        base_config = super(CylindricalNot, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

print("CylindricalPad class layer defined")

def attention_3d_block(inputs,timesteps):
    # inputs.shape = (batch_size, time_steps, input_dim)
    input_dim = int(inputs.shape[2])
    time_steps=timesteps
    print("input shape ",inputs.shape)
    print(input_dim)

    varsVec=[]
    for x in range(0,inputs.shape[4]):
            var=Lambda(lambda element : element[:,:,:,:,x])(inputs)
            #var=contxt_padded = Lambda(lambda x: K.expand_dims(x,1))(var)
            #var=K.expand_dims(var, 2)
            print("inside")
            print(var.shape)
            var = Permute((2, 3, 1))(var)
            #var = Permute((2, 1, 3))(var)
            #var = var[:,:,np.newaxis]
            #var = Conv1D(filters=5 ,kernel_size=5,strides=1,padding='same',name='conv1_%d' % x)(var)
            print("inside Cyl")
            print(var.shape)
            
            #var = CylindricalPad(m=1,n=1)(var)
           
            var = Conv2D(filters=4 ,kernel_size=(3,3),strides=1,padding='same',name='conv2_%d' % x)(var)

            #var= CylindricalPadCausal(m=2,n=1)(var)
            #var = CylindricalNot(m=2,n=1)(var)

            #var = CylindricalPad(m=0,n=0)(var)

            var = Conv2D(filters=5 ,kernel_size=(2,2),strides=1,padding='same',activation='softmax',name='conv_final_softmax_%d' % x)(var)
            var = Permute((3, 1,2))(var)
            print("out")
            print(var.shape)
            #var = Permute((2, 1,3))(var)
            var = Lambda(lambda x: K.expand_dims(x,4))(var)
            varsVec.append(var)
    
    #merged = varsVec
    merged = concatenate(varsVec)
    print(merged.shape)
    
    
    #a = Permute((2, 1))(inputs)
    #a_probs = Conv1D(input_dim,3,strides=1,padding='same',activation='softmax')(inputs)
    #a = Reshape((-1,input_dim, time_steps))(a) # this line is not useful. It's just to know which dimension is what.
    #a = Conv2D(100,3,padding='same')(a)
    #neurVec=[]
    #for x in range(0,100):
    #    filterImg=Lambda(lambda element : element[:,x,:,:])(a)
    #    flatImg = Flatten()(filterImg)
    #    output = Dense(1, activation='sigmoid')(flatImg)
    #    neurVec.append(output)
    
    #a = concatenate(neurVec)
    #a_probs = Dense(100, activation='softmax')(a)
    #a = Reshape((input_dim, time_steps))(a)
    #a_probs =  K.permute_dimensions(a_probs,(0,2,1,3,4)) #, name='attention_vec ' % (depth)
    #output_attention_mul = merge([inputs, a_probs], name='attention_mul', mode='mul')
    output_attention_mul= Multiply()([inputs, merged]) #name='attention_mul'
    return output_attention_mul


class CNNLSTMROLL:
    @staticmethod
    def build(timeSteps,rows, cols,classes):
        
        inputNet = Input(shape=(timeSteps,1,rows, cols)) #batch_shape=(20, 7, 5) 
        
        #cyPad1=CylindricalPadLSTMCNN(m=2,n=1)(inputNet) #
        #print(cyPad1.shape)
        convlstm2d=ConvLSTM2D(5, kernel_size=(5,3), padding="same", dropout=0.25, recurrent_dropout=0.15,return_sequences=True)(inputNet)
        
        #Bidirectional(              ,merge_mode='concat')
        #convlstm2d=CylindricalPadLSTMCNN(m=0,n=1)(convlstm2d)
        #convlstm2d=ConvLSTM2D(10, kernel_size=(2,3), padding="valid", dropout=0.2, recurrent_dropout=0.1)(convlstm2d)
        #attention_mul = attention_3d_block(  convlstm2d,timeSteps) #
        #cyPad2=CylindricalPadLSTMCNN(m=1,n=3)(attention_mul)
        convlstm2d=ConvLSTM2D(10, kernel_size=(3,3), padding="same", dropout=0.25, recurrent_dropout=0.15,return_sequences=False)(convlstm2d)
        flat = Flatten()(convlstm2d)
        
        #flat=Flatten()(convlstm2d)

        classificationLayer=Dense(classes)(flat)
        classificationLayer=Activation("softmax")(classificationLayer)
        
        #classificationLayer=Activation("softmax")(classificationLayer)
        
        model=Model(inputNet,classificationLayer)
        return model
# Out:
# /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/rjpg/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-c2efce73b923> in <module>()
#      31 K.set_image_data_format('channels_first')
#      32 #tf.config.experimental.list_physical_devices('GPU')
# ---> 33 tf.config.list_physical_devices('GPU')
#      34 tf.test.is_gpu_available()
#      35
#
# AttributeError: module 'tensorflow' has no attribute 'config'

# %%
# load data
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split


def non_shuffling_train_test_split(X, y, test_size=0.2):
    i = int((1 - test_size) * X.shape[0]) + 1
    X_train, X_test = np.split(X, [i])
    y_train, y_test = np.split(y, [i])
    return X_train, X_test, y_train, y_test

# load all data
dfin = pd.read_csv('windows-size72-step12.csv',header=None)  #inputs 72 lines per sample
dfout = pd.read_csv('out-class-size72-step12.csv',header=None)  #output classes 

total_inputs,total_output = dfin.values.astype(np.float32),dfout.values.astype(np.int32)

# normalize
scaler = MinMaxScaler(feature_range=(0, 1))
total_inputs = scaler.fit_transform(total_inputs)

# every 72 lines is one input sample
total_inputs = np.reshape(total_inputs, (-1,72,8))
total_inputs = np.reshape(total_inputs, (-1,6,12,8))
print("############# total shapes #############")
print(total_inputs.shape)
print(total_output.size)

train_inputs, test_inputs, train_output, test_output = non_shuffling_train_test_split(total_inputs, total_output, test_size=0.2)
#train_inputs, test_inputs, train_output, test_output = train_test_split(total_inputs, total_output, test_size=0.20, random_state=42)
print("############# train shapes #############")
print(train_inputs.shape)
print(train_output.shape)

print("############# test shapes #############")
print(test_inputs.shape)
print(test_output.shape)
# Out:
# ############# total shapes #############
# (2876, 6, 12, 8)
# 2876
# ############# train shapes #############
# (2301, 6, 12, 8)
# (2301, 1)
# ############# test shapes #############
# (575, 6, 12, 8)
# (575, 1)

# %%
IMG_ROWS, IMG_COLS = 72, 8 # input image dimensions
NB_CLASSES = 5  # number of outputs = number of classes

X_train = train_inputs[:,:, np.newaxis, :, :]
y_train = np_utils.to_categorical(train_output, NB_CLASSES)
X_test = test_inputs[:,:, np.newaxis, :, :]
y_test = np_utils.to_categorical(test_output, NB_CLASSES)
#print(y_test.shape)

# %%
IMG_ROWS, IMG_COLS = 72, 8 # input image dimensions
NB_CLASSES = 5  # number of outputs = number of classes



OPTIMIZER = Adam()

model = CNNLSTMROLL.build(timeSteps=6,rows=12, cols=8,classes=5)
model.compile(loss="categorical_crossentropy", optimizer=OPTIMIZER,
	metrics=["accuracy"])

model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 6, 1, 12, 8)]     0
# _________________________________________________________________
# conv_lst_m2d (ConvLSTM2D)    (None, 6, 5, 12, 8)       1820
# _________________________________________________________________
# conv_lst_m2d_1 (ConvLSTM2D)  (None, 10, 12, 8)         5440
# _________________________________________________________________
# flatten (Flatten)            (None, 960)               0
# _________________________________________________________________
# dense (Dense)                (None, 5)                 4805
# _________________________________________________________________
# activation (Activation)      (None, 5)                 0
# =================================================================
# Total params: 12,065
# Trainable params: 12,065
# Non-trainable params: 0
# _________________________________________________________________

# %%
from IPython.display import SVG,display
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
import matplotlib.pyplot as plt

#dá erro mas funciona 
#plot_model(model, to_file='model.pdf',show_shapes=True)

modelSVG=SVG(model_to_dot(model,show_shapes=True).create(prog='dot', format='svg'))
display(modelSVG)

# %%
# !ls -l
# Out:
# total 18568
# -rw-r--r-- 1 root root    11504 Dec  7 17:01 out-class-size72-step12.csv
# drwxr-xr-x 1 root root     4096 Dec  2 22:04 sample_data
# -rw-r--r-- 1 root root 18994762 Dec  7 17:03 windows-size72-step12.csv

# %%
NB_EPOCH = 100
BATCH_SIZE = 64
VERBOSE = 1

#tbCallBack = TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True)
#esCallBack = EarlyStopping(monitor='val_acc', min_delta=0, patience=12, verbose=0, mode='max')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.01,patience=5, min_lr=0.0001)
best_checkpoint = ModelCheckpoint('CNNLSTM-polution.h5', monitor='val_accuracy', save_best_only=True, verbose=1)

history = model.fit(X_train, y_train, 
		batch_size=BATCH_SIZE, epochs=NB_EPOCH, 
		verbose=1, # 0 for no logging to stdout, 1 for progress bar logging, 2 for one log line per epoch.
		validation_data=(X_test,y_test),
		#validation_split=VALIDATION_SPLIT,
		callbacks=[best_checkpoint])
# Out:
# Epoch 1/100
# 36/36 [==============================] - ETA: 0s - loss: 1.5955 - accuracy: 0.2421
# Epoch 00001: val_accuracy improved from -inf to 0.24696, saving model to CNNLSTM-polution.h5
# 36/36 [==============================] - 4s 99ms/step - loss: 1.5955 - accuracy: 0.2421 - val_loss: 1.5864 - val_accuracy: 0.2470
# Epoch 2/100
# 36/36 [==============================] - ETA: 0s - loss: 1.4913 - accuracy: 0.3525
# Epoch 00002: val_accuracy improved from 0.24696 to 0.33391, saving model to CNNLSTM-polution.h5
# 36/36 [==============================] - 3s 85ms/step - loss: 1.4913 - accuracy: 0.3525 - val_loss: 1.4365 - val_accuracy: 0.3339
# Epoch 3/100
# 36/36 [==============================] - ETA: 0s - loss: 1.4314 - accuracy: 0.3698
# Epoch 00003: val_accuracy did not improve from 0.33391
# 36/36 [==============================] - 3s 75ms/step - loss: 1.4314 - accuracy: 0.3698 - val_loss: 1.4411 - val_accuracy: 0.3339
# Epoch 4/100
# 36/36 [==============================] - ETA: 0s - loss: 1.4244 - accuracy: 0.3729
# Epoch 00004: val_accuracy did not improve from 0.33391
# 36/36 [==============================] - 3s 79ms/step - loss: 1.4244 - accuracy: 0.3729 - val_loss: 1.4417 - val_accuracy: 0.3252
# Epoch 5/100
# 36/36 [==============================] - ETA: 0s - loss: 1.4068 - accuracy: 0.3868
# Epoch 00005: val_accuracy improved from 0.33391 to 0.35652, saving model to CNNLSTM-polution.h5
# 36/36 [==============================] - 3s 84ms/step - loss: 1.4068 - accuracy: 0.3868 - val_loss: 1.4336 - val_accuracy: 0.3565
# Epoch 6/100
# 36/36 [==============================] - ETA: 0s - loss: 1.4014 - accuracy: 0.3855
# Epoch 00006: val_accuracy did not improve from 0.35652
# 36/36 [==============================] - 3s 84ms/step - loss: 1.4014 - accuracy: 0.3855 - val_loss: 1.4412 - val_accuracy: 0.3270
# Epoch 7/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3912 - accuracy: 0.3981
# Epoch 00007: val_accuracy improved from 0.35652 to 0.36696, saving model to CNNLSTM-polution.h5
# 36/36 [==============================] - 3s 91ms/step - loss: 1.3912 - accuracy: 0.3981 - val_loss: 1.4193 - val_accuracy: 0.3670
# Epoch 8/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3941 - accuracy: 0.3933
# Epoch 00008: val_accuracy did not improve from 0.36696
# 36/36 [==============================] - 3s 77ms/step - loss: 1.3941 - accuracy: 0.3933 - val_loss: 1.4338 - val_accuracy: 0.3374
# Epoch 9/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3876 - accuracy: 0.3798
# Epoch 00009: val_accuracy did not improve from 0.36696
# 36/36 [==============================] - 3s 78ms/step - loss: 1.3876 - accuracy: 0.3798 - val_loss: 1.4211 - val_accuracy: 0.3357
# Epoch 10/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3847 - accuracy: 0.3998
# Epoch 00010: val_accuracy did not improve from 0.36696
# 36/36 [==============================] - 3s 77ms/step - loss: 1.3847 - accuracy: 0.3998 - val_loss: 1.4098 - val_accuracy: 0.3583
# Epoch 11/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3817 - accuracy: 0.3933
# Epoch 00011: val_accuracy did not improve from 0.36696
# 36/36 [==============================] - 3s 77ms/step - loss: 1.3817 - accuracy: 0.3933 - val_loss: 1.4124 - val_accuracy: 0.3409
# Epoch 12/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3780 - accuracy: 0.3946
# Epoch 00012: val_accuracy did not improve from 0.36696
# 36/36 [==============================] - 3s 84ms/step - loss: 1.3780 - accuracy: 0.3946 - val_loss: 1.4111 - val_accuracy: 0.3513
# Epoch 13/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3748 - accuracy: 0.4042
# Epoch 00013: val_accuracy did not improve from 0.36696
# 36/36 [==============================] - 3s 84ms/step - loss: 1.3748 - accuracy: 0.4042 - val_loss: 1.4000 - val_accuracy: 0.3461
# Epoch 14/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3751 - accuracy: 0.3998
# Epoch 00014: val_accuracy did not improve from 0.36696
# 36/36 [==============================] - 3s 83ms/step - loss: 1.3751 - accuracy: 0.3998 - val_loss: 1.4081 - val_accuracy: 0.3548
# Epoch 15/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3767 - accuracy: 0.3937
# Epoch 00015: val_accuracy improved from 0.36696 to 0.37043, saving model to CNNLSTM-polution.h5
# 36/36 [==============================] - 3s 79ms/step - loss: 1.3767 - accuracy: 0.3937 - val_loss: 1.3934 - val_accuracy: 0.3704
# Epoch 16/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3750 - accuracy: 0.3968
# Epoch 00016: val_accuracy did not improve from 0.37043
# 36/36 [==============================] - 3s 77ms/step - loss: 1.3750 - accuracy: 0.3968 - val_loss: 1.3942 - val_accuracy: 0.3704
# Epoch 17/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3706 - accuracy: 0.3998
# Epoch 00017: val_accuracy did not improve from 0.37043
# 36/36 [==============================] - 3s 80ms/step - loss: 1.3706 - accuracy: 0.3998 - val_loss: 1.3897 - val_accuracy: 0.3704
# Epoch 18/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3611 - accuracy: 0.4072
# Epoch 00018: val_accuracy did not improve from 0.37043
# 36/36 [==============================] - 3s 83ms/step - loss: 1.3611 - accuracy: 0.4072 - val_loss: 1.3996 - val_accuracy: 0.3478
# Epoch 19/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3607 - accuracy: 0.4107
# Epoch 00019: val_accuracy improved from 0.37043 to 0.37913, saving model to CNNLSTM-polution.h5
# 36/36 [==============================] - 3s 89ms/step - loss: 1.3607 - accuracy: 0.4107 - val_loss: 1.3930 - val_accuracy: 0.3791
# Epoch 20/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3610 - accuracy: 0.4098
# Epoch 00020: val_accuracy did not improve from 0.37913
# 36/36 [==============================] - 3s 82ms/step - loss: 1.3610 - accuracy: 0.4098 - val_loss: 1.3931 - val_accuracy: 0.3791
# Epoch 21/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3582 - accuracy: 0.4050
# Epoch 00021: val_accuracy did not improve from 0.37913
# 36/36 [==============================] - 3s 80ms/step - loss: 1.3582 - accuracy: 0.4050 - val_loss: 1.3871 - val_accuracy: 0.3565
# Epoch 22/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3559 - accuracy: 0.4085
# Epoch 00022: val_accuracy did not improve from 0.37913
# 36/36 [==============================] - 3s 93ms/step - loss: 1.3559 - accuracy: 0.4085 - val_loss: 1.3838 - val_accuracy: 0.3722
# Epoch 23/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3545 - accuracy: 0.4168
# Epoch 00023: val_accuracy did not improve from 0.37913
# 36/36 [==============================] - 3s 84ms/step - loss: 1.3545 - accuracy: 0.4168 - val_loss: 1.3766 - val_accuracy: 0.3670
# Epoch 24/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3569 - accuracy: 0.4033
# Epoch 00024: val_accuracy did not improve from 0.37913
# 36/36 [==============================] - 3s 83ms/step - loss: 1.3569 - accuracy: 0.4033 - val_loss: 1.3799 - val_accuracy: 0.3722
# Epoch 25/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3479 - accuracy: 0.4185
# Epoch 00025: val_accuracy did not improve from 0.37913
# 36/36 [==============================] - 3s 85ms/step - loss: 1.3479 - accuracy: 0.4185 - val_loss: 1.4000 - val_accuracy: 0.3670
# Epoch 26/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3455 - accuracy: 0.4094
# Epoch 00026: val_accuracy did not improve from 0.37913
# 36/36 [==============================] - 3s 85ms/step - loss: 1.3455 - accuracy: 0.4094 - val_loss: 1.3844 - val_accuracy: 0.3722
# Epoch 27/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3469 - accuracy: 0.4172
# Epoch 00027: val_accuracy did not improve from 0.37913
# 36/36 [==============================] - 3s 87ms/step - loss: 1.3469 - accuracy: 0.4172 - val_loss: 1.3801 - val_accuracy: 0.3652
# Epoch 28/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3426 - accuracy: 0.4168
# Epoch 00028: val_accuracy did not improve from 0.37913
# 36/36 [==============================] - 3s 89ms/step - loss: 1.3426 - accuracy: 0.4168 - val_loss: 1.4120 - val_accuracy: 0.3670
# Epoch 29/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3448 - accuracy: 0.4111
# Epoch 00029: val_accuracy did not improve from 0.37913
# 36/36 [==============================] - 3s 78ms/step - loss: 1.3448 - accuracy: 0.4111 - val_loss: 1.3750 - val_accuracy: 0.3687
# Epoch 30/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3398 - accuracy: 0.4137
# Epoch 00030: val_accuracy did not improve from 0.37913
# 36/36 [==============================] - 3s 84ms/step - loss: 1.3398 - accuracy: 0.4137 - val_loss: 1.3802 - val_accuracy: 0.3565
# Epoch 31/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3391 - accuracy: 0.4133
# Epoch 00031: val_accuracy did not improve from 0.37913
# 36/36 [==============================] - 3s 85ms/step - loss: 1.3391 - accuracy: 0.4133 - val_loss: 1.3755 - val_accuracy: 0.3774
# Epoch 32/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3417 - accuracy: 0.4133
# Epoch 00032: val_accuracy did not improve from 0.37913
# 36/36 [==============================] - 3s 82ms/step - loss: 1.3417 - accuracy: 0.4133 - val_loss: 1.3788 - val_accuracy: 0.3670
# Epoch 33/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3400 - accuracy: 0.4255
# Epoch 00033: val_accuracy improved from 0.37913 to 0.39130, saving model to CNNLSTM-polution.h5
# 36/36 [==============================] - 3s 87ms/step - loss: 1.3400 - accuracy: 0.4255 - val_loss: 1.3746 - val_accuracy: 0.3913
# Epoch 34/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3303 - accuracy: 0.4220
# Epoch 00034: val_accuracy did not improve from 0.39130
# 36/36 [==============================] - 3s 88ms/step - loss: 1.3303 - accuracy: 0.4220 - val_loss: 1.3635 - val_accuracy: 0.3722
# Epoch 35/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3226 - accuracy: 0.4216
# Epoch 00035: val_accuracy did not improve from 0.39130
# 36/36 [==============================] - 3s 83ms/step - loss: 1.3226 - accuracy: 0.4216 - val_loss: 1.3819 - val_accuracy: 0.3687
# Epoch 36/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3233 - accuracy: 0.4237
# Epoch 00036: val_accuracy did not improve from 0.39130
# 36/36 [==============================] - 3s 81ms/step - loss: 1.3233 - accuracy: 0.4237 - val_loss: 1.3696 - val_accuracy: 0.3739
# Epoch 37/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3207 - accuracy: 0.4185
# Epoch 00037: val_accuracy did not improve from 0.39130
# 36/36 [==============================] - 3s 81ms/step - loss: 1.3207 - accuracy: 0.4185 - val_loss: 1.3560 - val_accuracy: 0.3843
# Epoch 38/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3255 - accuracy: 0.4263
# Epoch 00038: val_accuracy did not improve from 0.39130
# 36/36 [==============================] - 3s 85ms/step - loss: 1.3255 - accuracy: 0.4263 - val_loss: 1.3594 - val_accuracy: 0.3861
# Epoch 39/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3193 - accuracy: 0.4281
# Epoch 00039: val_accuracy improved from 0.39130 to 0.39652, saving model to CNNLSTM-polution.h5
# 36/36 [==============================] - 3s 94ms/step - loss: 1.3193 - accuracy: 0.4281 - val_loss: 1.3538 - val_accuracy: 0.3965
# Epoch 40/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3217 - accuracy: 0.4259
# Epoch 00040: val_accuracy did not improve from 0.39652
# 36/36 [==============================] - 3s 82ms/step - loss: 1.3217 - accuracy: 0.4259 - val_loss: 1.3597 - val_accuracy: 0.3878
# Epoch 41/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3204 - accuracy: 0.4359
# Epoch 00041: val_accuracy did not improve from 0.39652
# 36/36 [==============================] - 3s 85ms/step - loss: 1.3204 - accuracy: 0.4359 - val_loss: 1.3499 - val_accuracy: 0.3965
# Epoch 42/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3178 - accuracy: 0.4285
# Epoch 00042: val_accuracy did not improve from 0.39652
# 36/36 [==============================] - 3s 78ms/step - loss: 1.3178 - accuracy: 0.4285 - val_loss: 1.3681 - val_accuracy: 0.3791
# Epoch 43/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3117 - accuracy: 0.4281
# Epoch 00043: val_accuracy did not improve from 0.39652
# 36/36 [==============================] - 3s 87ms/step - loss: 1.3117 - accuracy: 0.4281 - val_loss: 1.3497 - val_accuracy: 0.3861
# Epoch 44/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3212 - accuracy: 0.4194
# Epoch 00044: val_accuracy did not improve from 0.39652
# 36/36 [==============================] - 3s 77ms/step - loss: 1.3212 - accuracy: 0.4194 - val_loss: 1.3482 - val_accuracy: 0.3826
# Epoch 45/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3133 - accuracy: 0.4237
# Epoch 00045: val_accuracy did not improve from 0.39652
# 36/36 [==============================] - 3s 81ms/step - loss: 1.3133 - accuracy: 0.4237 - val_loss: 1.3597 - val_accuracy: 0.3861
# Epoch 46/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3071 - accuracy: 0.4337
# Epoch 00046: val_accuracy did not improve from 0.39652
# 36/36 [==============================] - 3s 87ms/step - loss: 1.3071 - accuracy: 0.4337 - val_loss: 1.3425 - val_accuracy: 0.3774
# Epoch 47/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3163 - accuracy: 0.4229
# Epoch 00047: val_accuracy did not improve from 0.39652
# 36/36 [==============================] - 3s 78ms/step - loss: 1.3163 - accuracy: 0.4229 - val_loss: 1.3461 - val_accuracy: 0.3896
# Epoch 48/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3142 - accuracy: 0.4316
# Epoch 00048: val_accuracy did not improve from 0.39652
# 36/36 [==============================] - 3s 80ms/step - loss: 1.3142 - accuracy: 0.4316 - val_loss: 1.3479 - val_accuracy: 0.3791
# Epoch 49/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3061 - accuracy: 0.4372
# Epoch 00049: val_accuracy did not improve from 0.39652
# 36/36 [==============================] - 3s 91ms/step - loss: 1.3061 - accuracy: 0.4372 - val_loss: 1.3495 - val_accuracy: 0.3913
# Epoch 50/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3061 - accuracy: 0.4272
# Epoch 00050: val_accuracy did not improve from 0.39652
# 36/36 [==============================] - 3s 84ms/step - loss: 1.3061 - accuracy: 0.4272 - val_loss: 1.3464 - val_accuracy: 0.3791
# Epoch 51/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3107 - accuracy: 0.4250
# Epoch 00051: val_accuracy did not improve from 0.39652
# 36/36 [==============================] - 3s 80ms/step - loss: 1.3107 - accuracy: 0.4250 - val_loss: 1.3572 - val_accuracy: 0.3757
# Epoch 52/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3041 - accuracy: 0.4311
# Epoch 00052: val_accuracy did not improve from 0.39652
# 36/36 [==============================] - 3s 82ms/step - loss: 1.3041 - accuracy: 0.4311 - val_loss: 1.3595 - val_accuracy: 0.3809
# Epoch 53/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3015 - accuracy: 0.4316
# Epoch 00053: val_accuracy did not improve from 0.39652
# 36/36 [==============================] - 3s 87ms/step - loss: 1.3015 - accuracy: 0.4316 - val_loss: 1.3487 - val_accuracy: 0.3791
# Epoch 54/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3028 - accuracy: 0.4363
# Epoch 00054: val_accuracy did not improve from 0.39652
# 36/36 [==============================] - 3s 84ms/step - loss: 1.3028 - accuracy: 0.4363 - val_loss: 1.3421 - val_accuracy: 0.3930
# Epoch 55/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3006 - accuracy: 0.4372
# Epoch 00055: val_accuracy did not improve from 0.39652
# 36/36 [==============================] - 3s 84ms/step - loss: 1.3006 - accuracy: 0.4372 - val_loss: 1.3404 - val_accuracy: 0.3878
# Epoch 56/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3014 - accuracy: 0.4359
# Epoch 00056: val_accuracy improved from 0.39652 to 0.41043, saving model to CNNLSTM-polution.h5
# 36/36 [==============================] - 3s 88ms/step - loss: 1.3014 - accuracy: 0.4359 - val_loss: 1.3393 - val_accuracy: 0.4104
# Epoch 57/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2944 - accuracy: 0.4368
# Epoch 00057: val_accuracy did not improve from 0.41043
# 36/36 [==============================] - 3s 86ms/step - loss: 1.2944 - accuracy: 0.4368 - val_loss: 1.3450 - val_accuracy: 0.3948
# Epoch 58/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2980 - accuracy: 0.4433
# Epoch 00058: val_accuracy improved from 0.41043 to 0.41217, saving model to CNNLSTM-polution.h5
# 36/36 [==============================] - 3s 96ms/step - loss: 1.2980 - accuracy: 0.4433 - val_loss: 1.3359 - val_accuracy: 0.4122
# Epoch 59/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2917 - accuracy: 0.4402
# Epoch 00059: val_accuracy improved from 0.41217 to 0.41565, saving model to CNNLSTM-polution.h5
# 36/36 [==============================] - 3s 80ms/step - loss: 1.2917 - accuracy: 0.4402 - val_loss: 1.3307 - val_accuracy: 0.4157
# Epoch 60/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2898 - accuracy: 0.4298
# Epoch 00060: val_accuracy did not improve from 0.41565
# 36/36 [==============================] - 3s 81ms/step - loss: 1.2898 - accuracy: 0.4298 - val_loss: 1.3581 - val_accuracy: 0.3843
# Epoch 61/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2943 - accuracy: 0.4398
# Epoch 00061: val_accuracy did not improve from 0.41565
# 36/36 [==============================] - 3s 87ms/step - loss: 1.2943 - accuracy: 0.4398 - val_loss: 1.3349 - val_accuracy: 0.3948
# Epoch 62/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2973 - accuracy: 0.4233
# Epoch 00062: val_accuracy improved from 0.41565 to 0.42957, saving model to CNNLSTM-polution.h5
# 36/36 [==============================] - 3s 87ms/step - loss: 1.2973 - accuracy: 0.4233 - val_loss: 1.3365 - val_accuracy: 0.4296
# Epoch 63/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2956 - accuracy: 0.4359
# Epoch 00063: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 87ms/step - loss: 1.2956 - accuracy: 0.4359 - val_loss: 1.3402 - val_accuracy: 0.4000
# Epoch 64/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2828 - accuracy: 0.4498
# Epoch 00064: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 91ms/step - loss: 1.2828 - accuracy: 0.4498 - val_loss: 1.3373 - val_accuracy: 0.4017
# Epoch 65/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2788 - accuracy: 0.4342
# Epoch 00065: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 86ms/step - loss: 1.2788 - accuracy: 0.4342 - val_loss: 1.3365 - val_accuracy: 0.4052
# Epoch 66/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2833 - accuracy: 0.4398
# Epoch 00066: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 86ms/step - loss: 1.2833 - accuracy: 0.4398 - val_loss: 1.3360 - val_accuracy: 0.3965
# Epoch 67/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2873 - accuracy: 0.4350
# Epoch 00067: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 80ms/step - loss: 1.2873 - accuracy: 0.4350 - val_loss: 1.3273 - val_accuracy: 0.4087
# Epoch 68/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2777 - accuracy: 0.4463
# Epoch 00068: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 88ms/step - loss: 1.2777 - accuracy: 0.4463 - val_loss: 1.3334 - val_accuracy: 0.4035
# Epoch 69/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2811 - accuracy: 0.4498
# Epoch 00069: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 89ms/step - loss: 1.2811 - accuracy: 0.4498 - val_loss: 1.3266 - val_accuracy: 0.4122
# Epoch 70/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2654 - accuracy: 0.4524
# Epoch 00070: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 84ms/step - loss: 1.2654 - accuracy: 0.4524 - val_loss: 1.3310 - val_accuracy: 0.4000
# Epoch 71/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2726 - accuracy: 0.4472
# Epoch 00071: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 83ms/step - loss: 1.2726 - accuracy: 0.4472 - val_loss: 1.3330 - val_accuracy: 0.4000
# Epoch 72/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2729 - accuracy: 0.4398
# Epoch 00072: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 88ms/step - loss: 1.2729 - accuracy: 0.4398 - val_loss: 1.3495 - val_accuracy: 0.3826
# Epoch 73/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2827 - accuracy: 0.4402
# Epoch 00073: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 86ms/step - loss: 1.2827 - accuracy: 0.4402 - val_loss: 1.3226 - val_accuracy: 0.4087
# Epoch 74/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2776 - accuracy: 0.4455
# Epoch 00074: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 4s 101ms/step - loss: 1.2776 - accuracy: 0.4455 - val_loss: 1.3521 - val_accuracy: 0.3878
# Epoch 75/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2663 - accuracy: 0.4472
# Epoch 00075: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 85ms/step - loss: 1.2663 - accuracy: 0.4472 - val_loss: 1.3231 - val_accuracy: 0.4139
# Epoch 76/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2736 - accuracy: 0.4350
# Epoch 00076: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 85ms/step - loss: 1.2736 - accuracy: 0.4350 - val_loss: 1.3287 - val_accuracy: 0.4104
# Epoch 77/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2717 - accuracy: 0.4437
# Epoch 00077: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 81ms/step - loss: 1.2717 - accuracy: 0.4437 - val_loss: 1.3364 - val_accuracy: 0.4017
# Epoch 78/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2701 - accuracy: 0.4502
# Epoch 00078: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 96ms/step - loss: 1.2701 - accuracy: 0.4502 - val_loss: 1.3353 - val_accuracy: 0.4087
# Epoch 79/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2631 - accuracy: 0.4537
# Epoch 00079: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 93ms/step - loss: 1.2631 - accuracy: 0.4537 - val_loss: 1.3304 - val_accuracy: 0.4226
# Epoch 80/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2582 - accuracy: 0.4520
# Epoch 00080: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 85ms/step - loss: 1.2582 - accuracy: 0.4520 - val_loss: 1.3231 - val_accuracy: 0.4157
# Epoch 81/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2611 - accuracy: 0.4402
# Epoch 00081: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 80ms/step - loss: 1.2611 - accuracy: 0.4402 - val_loss: 1.3445 - val_accuracy: 0.3983
# Epoch 82/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2655 - accuracy: 0.4433
# Epoch 00082: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 81ms/step - loss: 1.2655 - accuracy: 0.4433 - val_loss: 1.3364 - val_accuracy: 0.3948
# Epoch 83/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2677 - accuracy: 0.4555
# Epoch 00083: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 84ms/step - loss: 1.2677 - accuracy: 0.4555 - val_loss: 1.3394 - val_accuracy: 0.3896
# Epoch 84/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2584 - accuracy: 0.4576
# Epoch 00084: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 79ms/step - loss: 1.2584 - accuracy: 0.4576 - val_loss: 1.3308 - val_accuracy: 0.4122
# Epoch 85/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2613 - accuracy: 0.4498
# Epoch 00085: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 87ms/step - loss: 1.2613 - accuracy: 0.4498 - val_loss: 1.3472 - val_accuracy: 0.3983
# Epoch 86/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2627 - accuracy: 0.4576
# Epoch 00086: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 80ms/step - loss: 1.2627 - accuracy: 0.4576 - val_loss: 1.3503 - val_accuracy: 0.4035
# Epoch 87/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2511 - accuracy: 0.4628
# Epoch 00087: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 84ms/step - loss: 1.2511 - accuracy: 0.4628 - val_loss: 1.3246 - val_accuracy: 0.4052
# Epoch 88/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2460 - accuracy: 0.4681
# Epoch 00088: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 79ms/step - loss: 1.2460 - accuracy: 0.4681 - val_loss: 1.3280 - val_accuracy: 0.4296
# Epoch 89/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2588 - accuracy: 0.4472
# Epoch 00089: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 80ms/step - loss: 1.2588 - accuracy: 0.4472 - val_loss: 1.3508 - val_accuracy: 0.3930
# Epoch 90/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2594 - accuracy: 0.4646
# Epoch 00090: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 85ms/step - loss: 1.2594 - accuracy: 0.4646 - val_loss: 1.3231 - val_accuracy: 0.4226
# Epoch 91/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2373 - accuracy: 0.4611
# Epoch 00091: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 81ms/step - loss: 1.2373 - accuracy: 0.4611 - val_loss: 1.3231 - val_accuracy: 0.4157
# Epoch 92/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2449 - accuracy: 0.4594
# Epoch 00092: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 81ms/step - loss: 1.2449 - accuracy: 0.4594 - val_loss: 1.3324 - val_accuracy: 0.4226
# Epoch 93/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2306 - accuracy: 0.4737
# Epoch 00093: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 85ms/step - loss: 1.2306 - accuracy: 0.4737 - val_loss: 1.3337 - val_accuracy: 0.4035
# Epoch 94/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2459 - accuracy: 0.4615
# Epoch 00094: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 87ms/step - loss: 1.2459 - accuracy: 0.4615 - val_loss: 1.3220 - val_accuracy: 0.4191
# Epoch 95/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2332 - accuracy: 0.4702
# Epoch 00095: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 84ms/step - loss: 1.2332 - accuracy: 0.4702 - val_loss: 1.3343 - val_accuracy: 0.4174
# Epoch 96/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2275 - accuracy: 0.4789
# Epoch 00096: val_accuracy did not improve from 0.42957
# 36/36 [==============================] - 3s 82ms/step - loss: 1.2275 - accuracy: 0.4789 - val_loss: 1.3585 - val_accuracy: 0.4017
# Epoch 97/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2364 - accuracy: 0.4685
# Epoch 00097: val_accuracy improved from 0.42957 to 0.43478, saving model to CNNLSTM-polution.h5
# 36/36 [==============================] - 3s 87ms/step - loss: 1.2364 - accuracy: 0.4685 - val_loss: 1.3284 - val_accuracy: 0.4348
# Epoch 98/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2385 - accuracy: 0.4694
# Epoch 00098: val_accuracy did not improve from 0.43478
# 36/36 [==============================] - 3s 85ms/step - loss: 1.2385 - accuracy: 0.4694 - val_loss: 1.3382 - val_accuracy: 0.4243
# Epoch 99/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2292 - accuracy: 0.4694
# Epoch 00099: val_accuracy did not improve from 0.43478
# 36/36 [==============================] - 3s 85ms/step - loss: 1.2292 - accuracy: 0.4694 - val_loss: 1.3407 - val_accuracy: 0.4243
# Epoch 100/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2348 - accuracy: 0.4767
# Epoch 00100: val_accuracy did not improve from 0.43478
# 36/36 [==============================] - 3s 85ms/step - loss: 1.2348 - accuracy: 0.4767 - val_loss: 1.3555 - val_accuracy: 0.3722

# %%
import json,codecs
import numpy as np
def saveHist(path,history):
 
    new_hist = {}
    for key in list(history.history.keys()):
        if type(history.history[key]) == np.ndarray:
            new_hist[key] == history.history[key].tolist()
        elif type(history.history[key]) == list:
           #if  type(history.history[key][0]) == np.float64:
           new_hist[key] = list(map(float, history.history[key]))
 
    #print(new_hist)
    with codecs.open(path, 'w', encoding='utf-8') as f:
        json.dump(new_hist, f, separators=(',', ':'), sort_keys=True, indent=4) 
 
def loadHist(path):
    with codecs.open(path, 'r', encoding='utf-8') as f:
        n = json.loads(f.read())
    return n
 

saveHist('CNNLSTM-polution.hist',history)
hist=loadHist('CNNLSTM-polution.hist')

# %%
import matplotlib.pylab as plt

acc=np.array(hist['accuracy'])
#acc=acc[0:100]
#acc=np.append(acc,[0.7])
plt.plot(acc,'b--')
plt.plot(hist['val_accuracy'],'b',label='CNNLSTM')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.show()
# summarize history for loss
loss=np.array(hist['loss'])
#loss=np.append(loss,[2])
plt.plot(loss,'b--',label='train')
plt.plot(hist['val_loss'],'b',label='test')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from keras.models import load_model
model = load_model('CNNLSTM-polution.h5',custom_objects={'CylindricalPadLSTMCNN':CylindricalPadLSTMCNN})

# %%
from sklearn.metrics import classification_report, confusion_matrix

	
print('Confusion Matrix')
cm=confusion_matrix(np.argmax(y_test,axis=1), np.argmax(model.predict(X_test),axis=1))
print(cm)
scores = model.evaluate(X_test,y_test, verbose=0)
print("Dados Validação %s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

pred = model.predict(X_test)
predicted = np.argmax(pred, axis=1)
report = classification_report(np.argmax(y_test, axis=1), predicted,digits=4)
print(report)
# Out:
# Confusion Matrix
# [[85 20  5  2  3]
#  [37 63 24  9  9]
#  [14 48 46 17 15]
#  [ 5 25 32 19 27]
#  [ 5  9 15  4 37]]
# Dados Validação accuracy: 43.48%
#               precision    recall  f1-score   support
#
#            0     0.5822    0.7391    0.6513       115
#            1     0.3818    0.4437    0.4104       142
#            2     0.3770    0.3286    0.3511       140
#            3     0.3725    0.1759    0.2390       108
#            4     0.4066    0.5286    0.4596        70
#
#     accuracy                         0.4348       575
#    macro avg     0.4240    0.4432    0.4223       575
# weighted avg     0.4220    0.4348    0.4180       575

# %%
import seaborn as sns

def cm_analysis(y_true, y_pred, labels, ymap=None, figsize=(10,10)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels = [ymap[yi] for yi in labels]
    cm = confusion_matrix(y_true, y_pred)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    plt.savefig("LSTM-ATTENTION-CONV1D-BF-enegie.pdf")
    plt.show()
    
    
    
cm_analysis(np.argmax(y_test,axis=1),np.argmax(pred,axis=1), labels=["1","2","3","4","5"], ymap=None, figsize=(6,6))
