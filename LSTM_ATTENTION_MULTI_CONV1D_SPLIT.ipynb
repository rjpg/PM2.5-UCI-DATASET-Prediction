# %%
import tensorflow as tf
from keras import backend as K
from keras.models import Sequential
from keras.layers.convolutional import Conv2D, Conv1D
from keras.layers.convolutional import AveragePooling2D
from keras.layers.core import Activation, Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.datasets import mnist
from keras.utils import np_utils
from keras.optimizers import SGD, RMSprop, Adam
import matplotlib.pyplot as plt
from keras.callbacks import TensorBoard
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import ModelCheckpoint
from keras.engine.topology import Layer, InputSpec
from keras.layers import Input, Permute,  Reshape,  Lambda, Concatenate
from keras.layers.merge import concatenate
from keras.models import Model
from keras.layers.recurrent import LSTM
from keras.layers.wrappers import Bidirectional, TimeDistributed
from keras.layers import merge, Multiply


SINGLE_ATTENTION_VECTOR = False


def attention_conv_block(inputs,timesteps):
    varsVec=[]
    for x in range(0,inputs.shape[2]):
            var=Lambda(lambda element : element[:,:,x])(inputs)
            var=contxt_padded = Lambda(lambda x: K.expand_dims(x,2))(var)
            var = Conv1D(filters=5 ,kernel_size=3,strides=1,padding='same',name='conv2_%d' % x)(var)
            var = Conv1D(filters=1 ,kernel_size=3,strides=1,padding='same',activation='softmax',name='conv_final_softmax_%d' % x)(var)
            varsVec.append(var)
    
    merged = concatenate(varsVec)
    output_attention_mul= Multiply()([inputs, merged])
    return output_attention_mul


class LSTMATTBFnet:
    @staticmethod
    def build(timeSteps,variables,classes):
        inputNet = Input(shape=(timeSteps,variables)) #batch_shape=(20, 7, 5) 
        attBlock=attention_conv_block(inputNet,timeSteps)
        #lstm=Bidirectional(LSTM(100,recurrent_dropout=0.4,dropout=0.4),merge_mode='concat')(inputNet) #worse using stateful=True
        lstm=Bidirectional(LSTM(100,recurrent_dropout=0.1,dropout=0.1,return_sequences=False),merge_mode='concat')(attBlock) #worse using stateful=True 
        
        # a softmax classifier
        classificationLayer=Dense(classes,activation='softmax')(lstm)
        
        model=Model(inputNet,classificationLayer)
        return model

# %%
# load data
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split


def non_shuffling_train_test_split(X, y, test_size=0.2):
    i = int((1 - test_size) * X.shape[0]) + 1
    X_train, X_test = np.split(X, [i])
    y_train, y_test = np.split(y, [i])
    return X_train, X_test, y_train, y_test

# load all data
dfin = pd.read_csv('windows-size72-step12.csv',header=None)  #inputs 72 lines per sample
dfout = pd.read_csv('out-class-size72-step12.csv',header=None)  #output classes 

total_inputs,total_output = dfin.values.astype(np.float32),dfout.values.astype(np.int32)

# normalize
scaler = MinMaxScaler(feature_range=(0, 1))
total_inputs = scaler.fit_transform(total_inputs)

# every 72 lines is one input sample
total_inputs = np.reshape(total_inputs, (-1,72,8))
print("############# total shapes #############")
print(total_inputs.shape)
print(total_output.size)

train_inputs, test_inputs, train_output, test_output = non_shuffling_train_test_split(total_inputs, total_output, test_size=0.2)
#train_inputs, test_inputs, train_output, test_output = train_test_split(total_inputs, total_output, test_size=0.20, random_state=42)
print("############# train shapes #############")
print(train_inputs.shape)
print(train_output.shape)

print("############# test shapes #############")
print(test_inputs.shape)
print(test_output.shape)
# Out:
# ############# total shapes #############
# (2876, 72, 8)
# 2876
# ############# train shapes #############
# (2301, 72, 8)
# (2301, 1)
# ############# test shapes #############
# (575, 72, 8)
# (575, 1)

# %%
IMG_ROWS, IMG_COLS = 72, 8 # input image dimensions
NB_CLASSES = 5  # number of outputs = number of classes

X_train = train_inputs
y_train = np_utils.to_categorical(train_output, NB_CLASSES)
X_test = test_inputs
y_test = np_utils.to_categorical(test_output, NB_CLASSES)
print(y_test.shape)

OPTIMIZER = Adam()

model = LSTMATTBFnet.build(timeSteps=72,variables=8,classes=5)
model.compile(loss="categorical_crossentropy", optimizer=OPTIMIZER,
	metrics=["accuracy"])

model.summary()
# Out:
# (575, 5)
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 72, 8)]      0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 72)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 72)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 72)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 72)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 72)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 72)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 72)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 72)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 72, 1)        0           lambda[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 72, 1)        0           lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 72, 1)        0           lambda_4[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 72, 1)        0           lambda_6[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 72, 1)        0           lambda_8[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 72, 1)        0           lambda_10[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 72, 1)        0           lambda_12[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 72, 1)        0           lambda_14[0][0]
# __________________________________________________________________________________________________
# conv2_0 (Conv1D)                (None, 72, 5)        20          lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2_1 (Conv1D)                (None, 72, 5)        20          lambda_3[0][0]
# __________________________________________________________________________________________________
# conv2_2 (Conv1D)                (None, 72, 5)        20          lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2_3 (Conv1D)                (None, 72, 5)        20          lambda_7[0][0]
# __________________________________________________________________________________________________
# conv2_4 (Conv1D)                (None, 72, 5)        20          lambda_9[0][0]
# __________________________________________________________________________________________________
# conv2_5 (Conv1D)                (None, 72, 5)        20          lambda_11[0][0]
# __________________________________________________________________________________________________
# conv2_6 (Conv1D)                (None, 72, 5)        20          lambda_13[0][0]
# __________________________________________________________________________________________________
# conv2_7 (Conv1D)                (None, 72, 5)        20          lambda_15[0][0]
# __________________________________________________________________________________________________
# conv_final_softmax_0 (Conv1D)   (None, 72, 1)        16          conv2_0[0][0]
# __________________________________________________________________________________________________
# conv_final_softmax_1 (Conv1D)   (None, 72, 1)        16          conv2_1[0][0]
# __________________________________________________________________________________________________
# conv_final_softmax_2 (Conv1D)   (None, 72, 1)        16          conv2_2[0][0]
# __________________________________________________________________________________________________
# conv_final_softmax_3 (Conv1D)   (None, 72, 1)        16          conv2_3[0][0]
# __________________________________________________________________________________________________
# conv_final_softmax_4 (Conv1D)   (None, 72, 1)        16          conv2_4[0][0]
# __________________________________________________________________________________________________
# conv_final_softmax_5 (Conv1D)   (None, 72, 1)        16          conv2_5[0][0]
# __________________________________________________________________________________________________
# conv_final_softmax_6 (Conv1D)   (None, 72, 1)        16          conv2_6[0][0]
# __________________________________________________________________________________________________
# conv_final_softmax_7 (Conv1D)   (None, 72, 1)        16          conv2_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 72, 8)        0           conv_final_softmax_0[0][0]
#                                                                  conv_final_softmax_1[0][0]
#                                                                  conv_final_softmax_2[0][0]
#                                                                  conv_final_softmax_3[0][0]
#                                                                  conv_final_softmax_4[0][0]
#                                                                  conv_final_softmax_5[0][0]
#                                                                  conv_final_softmax_6[0][0]
#                                                                  conv_final_softmax_7[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 72, 8)        0           input_1[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 200)          87200       multiply[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 5)            1005        bidirectional[0][0]
# ==================================================================================================
# Total params: 88,493
# Trainable params: 88,493
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from IPython.display import SVG,display
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
import matplotlib.pyplot as plt

modelSVG=SVG(model_to_dot(model,show_shapes=True).create(prog='dot', format='svg'))
display(modelSVG)
plot_model(model, to_file='model-att-conv1d.pdf',show_shapes=True)

# %%
NB_EPOCH = 100
BATCH_SIZE = 64
VERBOSE = 1

#tbCallBack = TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True)
#esCallBack = EarlyStopping(monitor='val_acc', min_delta=0, patience=12, verbose=0, mode='max')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.01,patience=5, min_lr=0.0001)
best_checkpoint = ModelCheckpoint('LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-polution.h5', monitor='val_accuracy', save_best_only=True, verbose=1)

history = model.fit(X_train, y_train, 
		batch_size=BATCH_SIZE, epochs=NB_EPOCH, 
		verbose=1, # 0 for no logging to stdout, 1 for progress bar logging, 2 for one log line per epoch.
		validation_data=(X_test,y_test),
		#validation_split=VALIDATION_SPLIT,
		callbacks=[reduce_lr,best_checkpoint])
# Out:
# Epoch 1/100
# 36/36 [==============================] - ETA: 0s - loss: 1.5465 - accuracy: 0.2855
# Epoch 00001: val_accuracy improved from -inf to 0.33391, saving model to LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-polution.h5
# 36/36 [==============================] - 22s 603ms/step - loss: 1.5465 - accuracy: 0.2855 - val_loss: 1.4521 - val_accuracy: 0.3339
# Epoch 2/100
# 36/36 [==============================] - ETA: 0s - loss: 1.4134 - accuracy: 0.3729
# Epoch 00002: val_accuracy did not improve from 0.33391
# 36/36 [==============================] - 21s 576ms/step - loss: 1.4134 - accuracy: 0.3729 - val_loss: 1.4776 - val_accuracy: 0.2922
# Epoch 3/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3925 - accuracy: 0.3816
# Epoch 00003: val_accuracy did not improve from 0.33391
# 36/36 [==============================] - 21s 594ms/step - loss: 1.3925 - accuracy: 0.3816 - val_loss: 1.4702 - val_accuracy: 0.2991
# Epoch 4/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3880 - accuracy: 0.3920
# Epoch 00004: val_accuracy improved from 0.33391 to 0.33739, saving model to LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-polution.h5
# 36/36 [==============================] - 21s 589ms/step - loss: 1.3880 - accuracy: 0.3920 - val_loss: 1.4090 - val_accuracy: 0.3374
# Epoch 5/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3614 - accuracy: 0.3994
# Epoch 00005: val_accuracy improved from 0.33739 to 0.37217, saving model to LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-polution.h5
# 36/36 [==============================] - 21s 570ms/step - loss: 1.3614 - accuracy: 0.3994 - val_loss: 1.3854 - val_accuracy: 0.3722
# Epoch 6/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3605 - accuracy: 0.4094
# Epoch 00006: val_accuracy did not improve from 0.37217
# 36/36 [==============================] - 20s 566ms/step - loss: 1.3605 - accuracy: 0.4094 - val_loss: 1.4011 - val_accuracy: 0.3670
# Epoch 7/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3497 - accuracy: 0.4103
# Epoch 00007: val_accuracy did not improve from 0.37217
# 36/36 [==============================] - 21s 585ms/step - loss: 1.3497 - accuracy: 0.4103 - val_loss: 1.3829 - val_accuracy: 0.3583
# Epoch 8/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3418 - accuracy: 0.4198
# Epoch 00008: val_accuracy improved from 0.37217 to 0.38261, saving model to LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-polution.h5
# 36/36 [==============================] - 21s 571ms/step - loss: 1.3418 - accuracy: 0.4198 - val_loss: 1.3691 - val_accuracy: 0.3826
# Epoch 9/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3366 - accuracy: 0.4220
# Epoch 00009: val_accuracy did not improve from 0.38261
# 36/36 [==============================] - 20s 563ms/step - loss: 1.3366 - accuracy: 0.4220 - val_loss: 1.4123 - val_accuracy: 0.3583
# Epoch 10/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3324 - accuracy: 0.4059
# Epoch 00010: val_accuracy did not improve from 0.38261
# 36/36 [==============================] - 21s 580ms/step - loss: 1.3324 - accuracy: 0.4059 - val_loss: 1.3882 - val_accuracy: 0.3583
# Epoch 11/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3292 - accuracy: 0.4194
# Epoch 00011: val_accuracy improved from 0.38261 to 0.39478, saving model to LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-polution.h5
# 36/36 [==============================] - 21s 579ms/step - loss: 1.3292 - accuracy: 0.4194 - val_loss: 1.3580 - val_accuracy: 0.3948
# Epoch 12/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3270 - accuracy: 0.4333
# Epoch 00012: val_accuracy did not improve from 0.39478
# 36/36 [==============================] - 21s 586ms/step - loss: 1.3270 - accuracy: 0.4333 - val_loss: 1.4235 - val_accuracy: 0.3548
# Epoch 13/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3191 - accuracy: 0.4316
# Epoch 00013: val_accuracy did not improve from 0.39478
# 36/36 [==============================] - 21s 588ms/step - loss: 1.3191 - accuracy: 0.4316 - val_loss: 1.3644 - val_accuracy: 0.3739
# Epoch 14/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3204 - accuracy: 0.4259
# Epoch 00014: val_accuracy did not improve from 0.39478
# 36/36 [==============================] - 20s 567ms/step - loss: 1.3204 - accuracy: 0.4259 - val_loss: 1.3769 - val_accuracy: 0.3704
# Epoch 15/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3186 - accuracy: 0.4242
# Epoch 00015: val_accuracy did not improve from 0.39478
# 36/36 [==============================] - 21s 572ms/step - loss: 1.3186 - accuracy: 0.4242 - val_loss: 1.3640 - val_accuracy: 0.3826
# Epoch 16/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3116 - accuracy: 0.4237
# Epoch 00016: val_accuracy improved from 0.39478 to 0.40870, saving model to LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-polution.h5
# 36/36 [==============================] - 21s 574ms/step - loss: 1.3116 - accuracy: 0.4237 - val_loss: 1.3428 - val_accuracy: 0.4087
# Epoch 17/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3086 - accuracy: 0.4333
# Epoch 00017: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 583ms/step - loss: 1.3086 - accuracy: 0.4333 - val_loss: 1.3902 - val_accuracy: 0.3948
# Epoch 18/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3048 - accuracy: 0.4237
# Epoch 00018: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 574ms/step - loss: 1.3048 - accuracy: 0.4237 - val_loss: 1.4017 - val_accuracy: 0.3600
# Epoch 19/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3097 - accuracy: 0.4307
# Epoch 00019: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 551ms/step - loss: 1.3097 - accuracy: 0.4307 - val_loss: 1.4193 - val_accuracy: 0.3635
# Epoch 20/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3015 - accuracy: 0.4346
# Epoch 00020: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 569ms/step - loss: 1.3015 - accuracy: 0.4346 - val_loss: 1.3833 - val_accuracy: 0.3617
# Epoch 21/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2987 - accuracy: 0.4389
# Epoch 00021: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 586ms/step - loss: 1.2987 - accuracy: 0.4389 - val_loss: 1.3452 - val_accuracy: 0.3878
# Epoch 22/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2831 - accuracy: 0.4342
# Epoch 00022: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 596ms/step - loss: 1.2831 - accuracy: 0.4342 - val_loss: 1.3434 - val_accuracy: 0.3930
# Epoch 23/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2775 - accuracy: 0.4537
# Epoch 00023: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 565ms/step - loss: 1.2775 - accuracy: 0.4537 - val_loss: 1.3423 - val_accuracy: 0.3878
# Epoch 24/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2754 - accuracy: 0.4459
# Epoch 00024: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 576ms/step - loss: 1.2754 - accuracy: 0.4459 - val_loss: 1.3372 - val_accuracy: 0.3878
# Epoch 25/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2714 - accuracy: 0.4546
# Epoch 00025: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 574ms/step - loss: 1.2714 - accuracy: 0.4546 - val_loss: 1.3432 - val_accuracy: 0.3965
# Epoch 26/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2726 - accuracy: 0.4437
# Epoch 00026: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 581ms/step - loss: 1.2726 - accuracy: 0.4437 - val_loss: 1.3396 - val_accuracy: 0.4000
# Epoch 27/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2712 - accuracy: 0.4559
# Epoch 00027: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 19s 536ms/step - loss: 1.2712 - accuracy: 0.4559 - val_loss: 1.3393 - val_accuracy: 0.3965
# Epoch 28/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2685 - accuracy: 0.4498
# Epoch 00028: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 575ms/step - loss: 1.2685 - accuracy: 0.4498 - val_loss: 1.3397 - val_accuracy: 0.3965
# Epoch 29/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2672 - accuracy: 0.4546
# Epoch 00029: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 582ms/step - loss: 1.2672 - accuracy: 0.4546 - val_loss: 1.3403 - val_accuracy: 0.3948
# Epoch 30/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2664 - accuracy: 0.4581
# Epoch 00030: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 580ms/step - loss: 1.2664 - accuracy: 0.4581 - val_loss: 1.3416 - val_accuracy: 0.3878
# Epoch 31/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2687 - accuracy: 0.4472
# Epoch 00031: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 547ms/step - loss: 1.2687 - accuracy: 0.4472 - val_loss: 1.3450 - val_accuracy: 0.3930
# Epoch 32/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2677 - accuracy: 0.4433
# Epoch 00032: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 562ms/step - loss: 1.2677 - accuracy: 0.4433 - val_loss: 1.3409 - val_accuracy: 0.3791
# Epoch 33/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2692 - accuracy: 0.4641
# Epoch 00033: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 556ms/step - loss: 1.2692 - accuracy: 0.4641 - val_loss: 1.3398 - val_accuracy: 0.3861
# Epoch 34/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2615 - accuracy: 0.4559
# Epoch 00034: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 565ms/step - loss: 1.2615 - accuracy: 0.4559 - val_loss: 1.3386 - val_accuracy: 0.3948
# Epoch 35/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2605 - accuracy: 0.4515
# Epoch 00035: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 559ms/step - loss: 1.2605 - accuracy: 0.4515 - val_loss: 1.3424 - val_accuracy: 0.3774
# Epoch 36/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2638 - accuracy: 0.4489
# Epoch 00036: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 560ms/step - loss: 1.2638 - accuracy: 0.4489 - val_loss: 1.3407 - val_accuracy: 0.4000
# Epoch 37/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2601 - accuracy: 0.4589
# Epoch 00037: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 556ms/step - loss: 1.2601 - accuracy: 0.4589 - val_loss: 1.3421 - val_accuracy: 0.3948
# Epoch 38/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2648 - accuracy: 0.4520
# Epoch 00038: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 588ms/step - loss: 1.2648 - accuracy: 0.4520 - val_loss: 1.3438 - val_accuracy: 0.3774
# Epoch 39/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2603 - accuracy: 0.4624
# Epoch 00039: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 563ms/step - loss: 1.2603 - accuracy: 0.4624 - val_loss: 1.3413 - val_accuracy: 0.4035
# Epoch 40/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2672 - accuracy: 0.4542
# Epoch 00040: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 19s 541ms/step - loss: 1.2672 - accuracy: 0.4542 - val_loss: 1.3407 - val_accuracy: 0.4017
# Epoch 41/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2570 - accuracy: 0.4550
# Epoch 00041: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 557ms/step - loss: 1.2570 - accuracy: 0.4550 - val_loss: 1.3452 - val_accuracy: 0.3826
# Epoch 42/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2601 - accuracy: 0.4502
# Epoch 00042: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 560ms/step - loss: 1.2601 - accuracy: 0.4502 - val_loss: 1.3386 - val_accuracy: 0.3930
# Epoch 43/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2659 - accuracy: 0.4633
# Epoch 00043: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 558ms/step - loss: 1.2659 - accuracy: 0.4633 - val_loss: 1.3404 - val_accuracy: 0.3983
# Epoch 44/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2644 - accuracy: 0.4476
# Epoch 00044: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 557ms/step - loss: 1.2644 - accuracy: 0.4476 - val_loss: 1.3432 - val_accuracy: 0.3843
# Epoch 45/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2619 - accuracy: 0.4420
# Epoch 00045: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 580ms/step - loss: 1.2619 - accuracy: 0.4420 - val_loss: 1.3413 - val_accuracy: 0.3948
# Epoch 46/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2563 - accuracy: 0.4546
# Epoch 00046: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 556ms/step - loss: 1.2563 - accuracy: 0.4546 - val_loss: 1.3490 - val_accuracy: 0.3965
# Epoch 47/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2623 - accuracy: 0.4515
# Epoch 00047: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 556ms/step - loss: 1.2623 - accuracy: 0.4515 - val_loss: 1.3451 - val_accuracy: 0.3948
# Epoch 48/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2591 - accuracy: 0.4546
# Epoch 00048: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 568ms/step - loss: 1.2591 - accuracy: 0.4546 - val_loss: 1.3419 - val_accuracy: 0.3896
# Epoch 49/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2552 - accuracy: 0.4733
# Epoch 00049: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 561ms/step - loss: 1.2552 - accuracy: 0.4733 - val_loss: 1.3408 - val_accuracy: 0.3930
# Epoch 50/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2496 - accuracy: 0.4633
# Epoch 00050: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 584ms/step - loss: 1.2496 - accuracy: 0.4633 - val_loss: 1.3443 - val_accuracy: 0.3843
# Epoch 51/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2604 - accuracy: 0.4524
# Epoch 00051: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 570ms/step - loss: 1.2604 - accuracy: 0.4524 - val_loss: 1.3387 - val_accuracy: 0.3983
# Epoch 52/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2548 - accuracy: 0.4568
# Epoch 00052: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 551ms/step - loss: 1.2548 - accuracy: 0.4568 - val_loss: 1.3416 - val_accuracy: 0.3843
# Epoch 53/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2560 - accuracy: 0.4668
# Epoch 00053: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 564ms/step - loss: 1.2560 - accuracy: 0.4668 - val_loss: 1.3404 - val_accuracy: 0.3861
# Epoch 54/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2497 - accuracy: 0.4563
# Epoch 00054: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 570ms/step - loss: 1.2497 - accuracy: 0.4563 - val_loss: 1.3424 - val_accuracy: 0.3913
# Epoch 55/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2491 - accuracy: 0.4633
# Epoch 00055: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 588ms/step - loss: 1.2491 - accuracy: 0.4633 - val_loss: 1.3484 - val_accuracy: 0.3983
# Epoch 56/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2468 - accuracy: 0.4624
# Epoch 00056: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 562ms/step - loss: 1.2468 - accuracy: 0.4624 - val_loss: 1.3444 - val_accuracy: 0.3843
# Epoch 57/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2482 - accuracy: 0.4624
# Epoch 00057: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 573ms/step - loss: 1.2482 - accuracy: 0.4624 - val_loss: 1.3445 - val_accuracy: 0.3965
# Epoch 58/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2510 - accuracy: 0.4650
# Epoch 00058: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 555ms/step - loss: 1.2510 - accuracy: 0.4650 - val_loss: 1.3446 - val_accuracy: 0.3861
# Epoch 59/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2510 - accuracy: 0.4602
# Epoch 00059: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 576ms/step - loss: 1.2510 - accuracy: 0.4602 - val_loss: 1.3399 - val_accuracy: 0.3843
# Epoch 60/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2451 - accuracy: 0.4672
# Epoch 00060: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 567ms/step - loss: 1.2451 - accuracy: 0.4672 - val_loss: 1.3418 - val_accuracy: 0.3861
# Epoch 61/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2506 - accuracy: 0.4663
# Epoch 00061: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 579ms/step - loss: 1.2506 - accuracy: 0.4663 - val_loss: 1.3411 - val_accuracy: 0.3896
# Epoch 62/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2506 - accuracy: 0.4607
# Epoch 00062: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 560ms/step - loss: 1.2506 - accuracy: 0.4607 - val_loss: 1.3436 - val_accuracy: 0.3878
# Epoch 63/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2513 - accuracy: 0.4650
# Epoch 00063: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 556ms/step - loss: 1.2513 - accuracy: 0.4650 - val_loss: 1.3410 - val_accuracy: 0.3861
# Epoch 64/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2510 - accuracy: 0.4581
# Epoch 00064: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 556ms/step - loss: 1.2510 - accuracy: 0.4581 - val_loss: 1.3450 - val_accuracy: 0.3930
# Epoch 65/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2477 - accuracy: 0.4650
# Epoch 00065: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 562ms/step - loss: 1.2477 - accuracy: 0.4650 - val_loss: 1.3411 - val_accuracy: 0.3843
# Epoch 66/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2468 - accuracy: 0.4546
# Epoch 00066: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 559ms/step - loss: 1.2468 - accuracy: 0.4546 - val_loss: 1.3451 - val_accuracy: 0.3930
# Epoch 67/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2413 - accuracy: 0.4620
# Epoch 00067: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 558ms/step - loss: 1.2413 - accuracy: 0.4620 - val_loss: 1.3460 - val_accuracy: 0.3861
# Epoch 68/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2461 - accuracy: 0.4650
# Epoch 00068: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 568ms/step - loss: 1.2461 - accuracy: 0.4650 - val_loss: 1.3374 - val_accuracy: 0.3913
# Epoch 69/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2473 - accuracy: 0.4672
# Epoch 00069: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 548ms/step - loss: 1.2473 - accuracy: 0.4672 - val_loss: 1.3384 - val_accuracy: 0.3843
# Epoch 70/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2373 - accuracy: 0.4694
# Epoch 00070: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 19s 535ms/step - loss: 1.2373 - accuracy: 0.4694 - val_loss: 1.3444 - val_accuracy: 0.3878
# Epoch 71/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2407 - accuracy: 0.4542
# Epoch 00071: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 564ms/step - loss: 1.2407 - accuracy: 0.4542 - val_loss: 1.3466 - val_accuracy: 0.3948
# Epoch 72/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2374 - accuracy: 0.4681
# Epoch 00072: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 550ms/step - loss: 1.2374 - accuracy: 0.4681 - val_loss: 1.3519 - val_accuracy: 0.3861
# Epoch 73/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2387 - accuracy: 0.4581
# Epoch 00073: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 557ms/step - loss: 1.2387 - accuracy: 0.4581 - val_loss: 1.3402 - val_accuracy: 0.3896
# Epoch 74/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2364 - accuracy: 0.4720
# Epoch 00074: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 577ms/step - loss: 1.2364 - accuracy: 0.4720 - val_loss: 1.3432 - val_accuracy: 0.3896
# Epoch 75/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2351 - accuracy: 0.4733
# Epoch 00075: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 568ms/step - loss: 1.2351 - accuracy: 0.4733 - val_loss: 1.3474 - val_accuracy: 0.3896
# Epoch 76/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2375 - accuracy: 0.4650
# Epoch 00076: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 565ms/step - loss: 1.2375 - accuracy: 0.4650 - val_loss: 1.3471 - val_accuracy: 0.3896
# Epoch 77/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2362 - accuracy: 0.4668
# Epoch 00077: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 586ms/step - loss: 1.2362 - accuracy: 0.4668 - val_loss: 1.3440 - val_accuracy: 0.3913
# Epoch 78/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2384 - accuracy: 0.4624
# Epoch 00078: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 567ms/step - loss: 1.2384 - accuracy: 0.4624 - val_loss: 1.3465 - val_accuracy: 0.3948
# Epoch 79/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2379 - accuracy: 0.4672
# Epoch 00079: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 546ms/step - loss: 1.2379 - accuracy: 0.4672 - val_loss: 1.3460 - val_accuracy: 0.3948
# Epoch 80/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2361 - accuracy: 0.4650
# Epoch 00080: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 556ms/step - loss: 1.2361 - accuracy: 0.4650 - val_loss: 1.3469 - val_accuracy: 0.3826
# Epoch 81/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2397 - accuracy: 0.4628
# Epoch 00081: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 564ms/step - loss: 1.2397 - accuracy: 0.4628 - val_loss: 1.3417 - val_accuracy: 0.4017
# Epoch 82/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2407 - accuracy: 0.4672
# Epoch 00082: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 569ms/step - loss: 1.2407 - accuracy: 0.4672 - val_loss: 1.3493 - val_accuracy: 0.3913
# Epoch 83/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2393 - accuracy: 0.4598
# Epoch 00083: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 567ms/step - loss: 1.2393 - accuracy: 0.4598 - val_loss: 1.3367 - val_accuracy: 0.3948
# Epoch 84/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2320 - accuracy: 0.4737
# Epoch 00084: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 576ms/step - loss: 1.2320 - accuracy: 0.4737 - val_loss: 1.3389 - val_accuracy: 0.3948
# Epoch 85/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2314 - accuracy: 0.4654
# Epoch 00085: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 593ms/step - loss: 1.2314 - accuracy: 0.4654 - val_loss: 1.3492 - val_accuracy: 0.3826
# Epoch 86/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2344 - accuracy: 0.4659
# Epoch 00086: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 552ms/step - loss: 1.2344 - accuracy: 0.4659 - val_loss: 1.3402 - val_accuracy: 0.3913
# Epoch 87/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2249 - accuracy: 0.4707
# Epoch 00087: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 562ms/step - loss: 1.2249 - accuracy: 0.4707 - val_loss: 1.3419 - val_accuracy: 0.3913
# Epoch 88/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2317 - accuracy: 0.4698
# Epoch 00088: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 569ms/step - loss: 1.2317 - accuracy: 0.4698 - val_loss: 1.3467 - val_accuracy: 0.3983
# Epoch 89/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2396 - accuracy: 0.4598
# Epoch 00089: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 581ms/step - loss: 1.2396 - accuracy: 0.4598 - val_loss: 1.3418 - val_accuracy: 0.3913
# Epoch 90/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2351 - accuracy: 0.4772
# Epoch 00090: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 567ms/step - loss: 1.2351 - accuracy: 0.4772 - val_loss: 1.3432 - val_accuracy: 0.3983
# Epoch 91/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2274 - accuracy: 0.4741
# Epoch 00091: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 559ms/step - loss: 1.2274 - accuracy: 0.4741 - val_loss: 1.3409 - val_accuracy: 0.3843
# Epoch 92/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2282 - accuracy: 0.4715
# Epoch 00092: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 559ms/step - loss: 1.2282 - accuracy: 0.4715 - val_loss: 1.3405 - val_accuracy: 0.4035
# Epoch 93/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2282 - accuracy: 0.4772
# Epoch 00093: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 549ms/step - loss: 1.2282 - accuracy: 0.4772 - val_loss: 1.3426 - val_accuracy: 0.3965
# Epoch 94/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2283 - accuracy: 0.4681
# Epoch 00094: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 559ms/step - loss: 1.2283 - accuracy: 0.4681 - val_loss: 1.3449 - val_accuracy: 0.4017
# Epoch 95/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2281 - accuracy: 0.4650
# Epoch 00095: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 550ms/step - loss: 1.2281 - accuracy: 0.4650 - val_loss: 1.3425 - val_accuracy: 0.4017
# Epoch 96/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2219 - accuracy: 0.4685
# Epoch 00096: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 578ms/step - loss: 1.2219 - accuracy: 0.4685 - val_loss: 1.3472 - val_accuracy: 0.4052
# Epoch 97/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2239 - accuracy: 0.4711
# Epoch 00097: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 21s 584ms/step - loss: 1.2239 - accuracy: 0.4711 - val_loss: 1.3463 - val_accuracy: 0.3930
# Epoch 98/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2274 - accuracy: 0.4659
# Epoch 00098: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 20s 562ms/step - loss: 1.2274 - accuracy: 0.4659 - val_loss: 1.3361 - val_accuracy: 0.4017
# Epoch 99/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2276 - accuracy: 0.4637
# Epoch 00099: val_accuracy improved from 0.40870 to 0.41217, saving model to LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-polution.h5
# 36/36 [==============================] - 20s 554ms/step - loss: 1.2276 - accuracy: 0.4637 - val_loss: 1.3530 - val_accuracy: 0.4122
# Epoch 100/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2234 - accuracy: 0.4715
# Epoch 00100: val_accuracy did not improve from 0.41217
# 36/36 [==============================] - 21s 584ms/step - loss: 1.2234 - accuracy: 0.4715 - val_loss: 1.3407 - val_accuracy: 0.3965

# %%
import json,codecs
import numpy as np
def saveHist(path,history):
 
    new_hist = {}
    for key in list(history.history.keys()):
        if type(history.history[key]) == np.ndarray:
            new_hist[key] == history.history[key].tolist()
        elif type(history.history[key]) == list:
           #if  type(history.history[key][0]) == np.float64:
           new_hist[key] = list(map(float, history.history[key]))
 
    #print(new_hist)
    with codecs.open(path, 'w', encoding='utf-8') as f:
        json.dump(new_hist, f, separators=(',', ':'), sort_keys=True, indent=4) 
 
def loadHist(path):
    with codecs.open(path, 'r', encoding='utf-8') as f:
        n = json.loads(f.read())
    return n
 


saveHist('LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-polution.hist',history)
hist=loadHist('LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-polution.hist')

# %%
import matplotlib.pylab as plt

acc=np.array(hist['accuracy'])
#acc=acc[0:100]
#acc=np.append(acc,[0.7])
plt.plot(acc,'b--')
plt.plot(hist['val_accuracy'],'b',label='DNNC')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.show()
# summarize history for loss
loss=np.array(hist['loss'])
#loss=np.append(loss,[2])
plt.plot(loss,'b--',label='train')
plt.plot(hist['val_loss'],'b',label='test')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix

from keras.models import load_model
model = load_model('LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-polution.h5')

print('Confusion Matrix')
cm=confusion_matrix(np.argmax(y_test,axis=1), np.argmax(model.predict(X_test),axis=1))
print(cm)
scores = model.evaluate(X_test,y_test, verbose=0)
print("Dados Validação %s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

pred = model.predict(X_test)
predicted = np.argmax(pred, axis=1)
report = classification_report(np.argmax(y_test, axis=1), predicted,digits=4)
print(report)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Confusion Matrix
# [[75 26  5  6  3]
#  [26 74 13 18 11]
#  [ 7 57 27 32 17]
#  [ 4 30 17 38 19]
#  [ 5 14  1 27 23]]
# Dados Validação accuracy: 41.22%
#               precision    recall  f1-score   support
#
#            0     0.6410    0.6522    0.6466       115
#            1     0.3682    0.5211    0.4315       142
#            2     0.4286    0.1929    0.2660       140
#            3     0.3140    0.3519    0.3319       108
#            4     0.3151    0.3286    0.3217        70
#
#     accuracy                         0.4122       575
#    macro avg     0.4134    0.4093    0.3995       575
# weighted avg     0.4208    0.4122    0.4021       575

# %%
import seaborn as sns

def cm_analysis(y_true, y_pred, labels, ymap=None, figsize=(10,10)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels = [ymap[yi] for yi in labels]
    cm = confusion_matrix(y_true, y_pred)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    plt.savefig("LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-energie-CM.pdf")
    plt.show()
    
    
    
cm_analysis(np.argmax(y_test,axis=1),np.argmax(pred,axis=1), labels=["1","2","3","4","5"], ymap=None, figsize=(6,6))
