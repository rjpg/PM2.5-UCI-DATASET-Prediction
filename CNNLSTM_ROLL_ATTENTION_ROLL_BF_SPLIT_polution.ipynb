# %%
import tensorflow as tf
from keras import backend as K
from keras.models import Sequential
from keras.layers.convolutional import Conv2D, Conv3D
from keras.layers.convolutional import AveragePooling2D
from keras.layers.core import Activation, Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.datasets import mnist
from keras.utils import np_utils
from keras.optimizers import SGD, RMSprop, Adam
import matplotlib.pyplot as plt
from keras.callbacks import TensorBoard
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import ModelCheckpoint
from keras.engine.topology import Layer,InputSpec
from keras.layers import ConvLSTM2D
from keras.layers import Input, Permute,  Reshape,  Lambda, Concatenate
from keras.layers.merge import concatenate
from keras.models import Model
from keras.layers.wrappers import Bidirectional, TimeDistributed
from keras.layers import merge, Multiply

K.image_data_format()
K.set_image_data_format('channels_first')



K.image_data_format()
K.set_image_data_format('channels_first')
#tf.config.experimental.list_physical_devices('GPU')
tf.config.list_physical_devices('GPU')
tf.test.is_gpu_available()

print("tf.__version__ is", tf.__version__)
print("tf.keras.__version__ is:", tf.keras.__version__)

def _get_available_gpus():
    """Get a list of available gpu devices (formatted as strings).

    # Returns
        A list of available GPU devices.
    """
    #global _LOCAL_DEVICES
    if tfback._LOCAL_DEVICES is None:
        devices = tf.config.list_logical_devices()
        tfback._LOCAL_DEVICES = [x.name for x in devices]
    return [x for x in tfback._LOCAL_DEVICES if 'device:gpu' in x.lower()]

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))


class CylindricalPadLSTMCNN(Layer):

    def __init__(self, m=0,n=1, **kwargs):
        super(CylindricalPadLSTMCNN, self).__init__(**kwargs)
        self.n = n
        self.m = m
        assert n > 0, 'n must be positive'
        
    def build(self, input_shape):
        self.input_spec = [InputSpec(shape=input_shape)]
        super(CylindricalPadLSTMCNN, self).build(input_shape)  
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0],
                input_shape[1],
                    input_shape[2],
                    input_shape[3] + 2*self.m,
                    input_shape[4] + 2*self.n)

    def get_output_shape_for(self, input_shape):
        return (input_shape[0],
                input_shape[1],
                    input_shape[2],
                    input_shape[3] + 2*self.m,
                    input_shape[4] + 2*self.n)
    
    def call(self,testElement, mask=None):
        firstColumns=testElement[:,:,:,:,0:self.n]
        lastColumns=testElement[:,:,:,:,testElement.shape[4]-self.n:testElement.shape[4]]
        result=tf.concat([testElement,firstColumns], axis=4)
        result=tf.concat([lastColumns,result], axis=4)
        if self.m != 0 :
            #x = tf.placeholder(result.dtype, shape=[result.shape[0],result.shape[1],self.m,result.shape[3]])
            #y = tf.zeros_like(x,dtype=result.dtype)
            
            firstRows=result[:,:,:,0:self.m,:]
            
            y = tf.fill(tf.shape(firstRows), 0.)
            
            #y=tf.fill([result.shape[0],result.shape[1],self.m,result.shape[3]],0.)
            
            #y = tf.constant(0., shape=[result.shape[0],result.shape[1],self.m,result.shape[3]],dtype=result.dtype)
            result=tf.concat([y,result], axis=3)
            result=tf.concat([result,y], axis=3)
        
        return result

    def get_config(self):
        config = {'n': self.n,
        'm': self.m}
        base_config = super(CylindricalPadLSTMCNN, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

class CylindricalPad(Layer):

    def __init__(self, m=0,n=1, **kwargs):
        super(CylindricalPad, self).__init__(**kwargs)
        self.n = n
        self.m = m
        #assert n > 0, 'n must be positive'
        
    def build(self, input_shape):
        self.input_spec = [InputSpec(shape=input_shape)]
        super(CylindricalPad, self).build(input_shape)  
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0],
                    input_shape[1],
                    #input_shape[2] + self.m,
                    # ONLY ADD m 0's to the left for casusal padding
                    input_shape[2] + 2*self.m,
                    input_shape[3] + 2*self.n)

    def get_output_shape_for(self, input_shape):
        return (input_shape[0],
                    input_shape[1],
                    #input_shape[2] + self.m,
                    # ONLY ADD m 0's to the left for casusal padding
                    input_shape[2] + 2*self.m,
                    input_shape[3] + 2*self.n)
    
    def call(self,testElement, mask=None):
        #print(testElement.shape)
        firstColumns=testElement[:,:,:,0:self.n]
        lastColumns=testElement[:,:,:,testElement.shape[3]-self.n:testElement.shape[3]]
        result=tf.concat([testElement,firstColumns], axis=3)
        result=tf.concat([lastColumns,result], axis=3)
        if self.m != 0 :
          firstRows=result[:,:,0:self.m,:]
          y = tf.fill(tf.shape(firstRows), 0.)
          result=tf.concat([y,result], axis=2)
          result=tf.concat([result,y], axis=2)
          
        return result

    def get_config(self):
        config = {'n': self.n,
        'm': self.m}
        base_config = super(CylindricalPad, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

class CylindricalPadCausal(Layer):

    def __init__(self, m=0,n=1, **kwargs):
        super(CylindricalPadCausal, self).__init__(**kwargs)
        self.n = n
        self.m = m
        #assert n > 0, 'n must be positive'
        
    def build(self, input_shape):
        self.input_spec = [InputSpec(shape=input_shape)]
        super(CylindricalPadCausal, self).build(input_shape)  
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0],
                    input_shape[1],
                    #input_shape[2] + 2*self.m,
                    # ONLY ADD m 0's to the left for casusal padding
                    input_shape[2] + self.m,
                    input_shape[3] + 2*self.n)

    def get_output_shape_for(self, input_shape):
        return (input_shape[0],
                    input_shape[1],
                    #input_shape[2] + 2*self.m,
                    # ONLY ADD m 0's to the left for casusal padding
                    input_shape[2] + self.m,
                    input_shape[3] + 2*self.n)
    
    def call(self,testElement, mask=None):
        firstColumns=testElement[:,:,:,0:self.n]
        lastColumns=testElement[:,:,:,testElement.shape[3]-self.n:testElement.shape[3]]
        result=tf.concat([testElement,firstColumns], axis=3)
        result=tf.concat([lastColumns,result], axis=3)
        if self.m != 0 :
            #x = tf.placeholder(result.dtype, shape=[result.shape[0],result.shape[1],self.m,result.shape[3]])
            #y = tf.zeros_like(x,dtype=result.dtype)
            
            firstRows=result[:,:,0:self.m,:]
            
            #y = tf.fill(tf.shape(firstRows), 0.)
            sa=tf.shape(firstRows)[0]
            sb=tf.shape(firstRows)[1]
            sc=self.m
            sd=tf.shape(firstRows)[3]
            y = tf.fill([sa, sb,sc, sd], 0.)
            
            #y=tf.fill([result.shape[0],result.shape[1],self.m,result.shape[3]],0.)
            
            #y = tf.constant(0., shape=[result.shape[0],result.shape[1],self.m,result.shape[3]],dtype=result.dtype)
            result=tf.concat([y,result], axis=2)
            
            ########## only add 0's to de left for casusal pading
            #############result=tf.concat([result,y], axis=2)
        
        return result

    def get_config(self):
        config = {'n': self.n,
        'm': self.m}
        base_config = super(CylindricalPadCausal, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))


class CylindricalNot(Layer):

    def __init__(self, m=0,n=1, **kwargs):
        super(CylindricalNot, self).__init__(**kwargs)
        self.n = n
        self.m = m
        #assert n > 0, 'n must be positive'
        
    def build(self, input_shape):
        self.input_spec = [InputSpec(shape=input_shape)]
        super(CylindricalNot, self).build(input_shape)  
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0],
                    input_shape[1],
                    #input_shape[2] + 2*self.m,
                    # ONLY ADD m 0's to the left for casusal padding
                    input_shape[2] ,
                    input_shape[3] )

    def get_output_shape_for(self, input_shape):
        return (input_shape[0],
                    input_shape[1],
                    #input_shape[2] + 2*self.m,
                    # ONLY ADD m 0's to the left for casusal padding
                    input_shape[2] ,
                    input_shape[3] )
    
    def call(self,testElement, mask=None):
        
        return testElement

    def get_config(self):
        config = {'n': self.n,
        'm': self.m}
        base_config = super(CylindricalNot, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

print("CylindricalPad class layer defined")

def attention_3d_block(inputs,timesteps):
    # inputs.shape = (batch_size, time_steps, input_dim)
    input_dim = int(inputs.shape[2])
    time_steps=timesteps
    print("input shape ",inputs.shape)
    print(input_dim)

    varsVec=[]
    for x in range(0,inputs.shape[4]):
            var=Lambda(lambda element : element[:,:,:,:,x])(inputs)
            #var=contxt_padded = Lambda(lambda x: K.expand_dims(x,1))(var)
            #var=K.expand_dims(var, 2)
            print("inside")
            print(var.shape)
            var = Permute((2, 3, 1))(var)
            #var = Permute((2, 1, 3))(var)
            #var = var[:,:,np.newaxis]
            #var = Conv1D(filters=5 ,kernel_size=5,strides=1,padding='same',name='conv1_%d' % x)(var)
            print("inside Cyl")
            print(var.shape)
            
            #var = CylindricalPad(m=1,n=1)(var)
           
            var = Conv2D(filters=4 ,kernel_size=(3,3),strides=1,padding='same',name='conv2_%d' % x)(var)

            #var= CylindricalPadCausal(m=2,n=1)(var)
            #var = CylindricalNot(m=2,n=1)(var)

            #var = CylindricalPad(m=0,n=0)(var)

            var = Conv2D(filters=5 ,kernel_size=(2,2),strides=1,padding='same',activation='softmax',name='conv_final_softmax_%d' % x)(var)
            var = Permute((3, 1,2))(var)
            print("out")
            print(var.shape)
            #var = Permute((2, 1,3))(var)
            var = Lambda(lambda x: K.expand_dims(x,4))(var)
            varsVec.append(var)
    
    #merged = varsVec
    merged = concatenate(varsVec)
    print(merged.shape)
    
    
    #a = Permute((2, 1))(inputs)
    #a_probs = Conv1D(input_dim,3,strides=1,padding='same',activation='softmax')(inputs)
    #a = Reshape((-1,input_dim, time_steps))(a) # this line is not useful. It's just to know which dimension is what.
    #a = Conv2D(100,3,padding='same')(a)
    #neurVec=[]
    #for x in range(0,100):
    #    filterImg=Lambda(lambda element : element[:,x,:,:])(a)
    #    flatImg = Flatten()(filterImg)
    #    output = Dense(1, activation='sigmoid')(flatImg)
    #    neurVec.append(output)
    
    #a = concatenate(neurVec)
    #a_probs = Dense(100, activation='softmax')(a)
    #a = Reshape((input_dim, time_steps))(a)
    #a_probs =  K.permute_dimensions(a_probs,(0,2,1,3,4)) #, name='attention_vec ' % (depth)
    #output_attention_mul = merge([inputs, a_probs], name='attention_mul', mode='mul')
    output_attention_mul= Multiply()([inputs, merged]) #name='attention_mul'
    return output_attention_mul


class CNNLSTMROLL:
    @staticmethod
    def build(timeSteps,rows, cols,classes):
        
        inputNet = Input(shape=(timeSteps,1,rows, cols)) #batch_shape=(20, 7, 5) 
        
        cyPad1=CylindricalPadLSTMCNN(m=2,n=1)(inputNet) #
        #print(cyPad1.shape)
        convlstm2d=ConvLSTM2D(5, kernel_size=(5,3), padding="valid", dropout=0.25, recurrent_dropout=0.15,return_sequences=True)(cyPad1)
        
        #Bidirectional(              ,merge_mode='concat')
        #convlstm2d=CylindricalPadLSTMCNN(m=0,n=1)(convlstm2d)
        #convlstm2d=ConvLSTM2D(10, kernel_size=(2,3), padding="valid", dropout=0.2, recurrent_dropout=0.1)(convlstm2d)
        attention_mul = attention_3d_block(  convlstm2d,timeSteps) #
        cyPad2=CylindricalPadLSTMCNN(m=1,n=3)(attention_mul)
        convlstm2d=ConvLSTM2D(10, kernel_size=(3,3), padding="valid", dropout=0.25, recurrent_dropout=0.15,return_sequences=False)(cyPad2)
        flat = Flatten()(convlstm2d)
        
        #flat=Flatten()(convlstm2d)

        classificationLayer=Dense(classes)(flat)
        classificationLayer=Activation("softmax")(classificationLayer)
        
        #classificationLayer=Activation("softmax")(classificationLayer)
        
        model=Model(inputNet,classificationLayer)
        return model
# Out:
# tf.__version__ is 2.3.0
# tf.keras.__version__ is: 2.4.0
# CylindricalPad class layer defined

# %%
# load data
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split


def non_shuffling_train_test_split(X, y, test_size=0.2):
    i = int((1 - test_size) * X.shape[0]) + 1
    X_train, X_test = np.split(X, [i])
    y_train, y_test = np.split(y, [i])
    return X_train, X_test, y_train, y_test

# load all data
dfin = pd.read_csv('windows-size72-step12.csv',header=None)  #inputs 72 lines per sample
dfout = pd.read_csv('out-class-size72-step12.csv',header=None)  #output classes 

total_inputs,total_output = dfin.values.astype(np.float32),dfout.values.astype(np.int32)

# normalize
scaler = MinMaxScaler(feature_range=(0, 1))
total_inputs = scaler.fit_transform(total_inputs)

# every 72 lines is one input sample
total_inputs = np.reshape(total_inputs, (-1,72,8))
total_inputs = np.reshape(total_inputs, (-1,6,12,8))
print("############# total shapes #############")
print(total_inputs.shape)
print(total_output.size)

train_inputs, test_inputs, train_output, test_output = non_shuffling_train_test_split(total_inputs, total_output, test_size=0.2)
#train_inputs, test_inputs, train_output, test_output = train_test_split(total_inputs, total_output, test_size=0.20, random_state=42)
print("############# train shapes #############")
print(train_inputs.shape)
print(train_output.shape)

print("############# test shapes #############")
print(test_inputs.shape)
print(test_output.shape)
# Out:
# ############# total shapes #############
# (2876, 6, 12, 8)
# 2876
# ############# train shapes #############
# (2301, 6, 12, 8)
# (2301, 1)
# ############# test shapes #############
# (575, 6, 12, 8)
# (575, 1)

# %%
IMG_ROWS, IMG_COLS = 72, 8 # input image dimensions
NB_CLASSES = 5  # number of outputs = number of classes

X_train = train_inputs[:,:, np.newaxis, :, :]
y_train = np_utils.to_categorical(train_output, NB_CLASSES)
X_test = test_inputs[:,:, np.newaxis, :, :]
y_test = np_utils.to_categorical(test_output, NB_CLASSES)
#print(y_test.shape)

# %%
IMG_ROWS, IMG_COLS = 72, 8 # input image dimensions
NB_CLASSES = 5  # number of outputs = number of classes



OPTIMIZER = Adam()

model = CNNLSTMROLL.build(timeSteps=6,rows=12, cols=8,classes=5)
model.compile(loss="categorical_crossentropy", optimizer=OPTIMIZER,
	metrics=["accuracy"])

model.summary()
# Out:
# input shape  (None, 6, 5, 12, 8)
# 5
# inside
# (None, 6, 5, 12)
# inside Cyl
# (None, 5, 12, 6)
# out
# (None, 6, 5, 12)
# inside
# (None, 6, 5, 12)
# inside Cyl
# (None, 5, 12, 6)
# out
# (None, 6, 5, 12)
# inside
# (None, 6, 5, 12)
# inside Cyl
# (None, 5, 12, 6)
# out
# (None, 6, 5, 12)
# inside
# (None, 6, 5, 12)
# inside Cyl
# (None, 5, 12, 6)
# out
# (None, 6, 5, 12)
# inside
# (None, 6, 5, 12)
# inside Cyl
# (None, 5, 12, 6)
# out
# (None, 6, 5, 12)
# inside
# (None, 6, 5, 12)
# inside Cyl
# (None, 5, 12, 6)
# out
# (None, 6, 5, 12)
# inside
# (None, 6, 5, 12)
# inside Cyl
# (None, 5, 12, 6)
# out
# (None, 6, 5, 12)
# inside
# (None, 6, 5, 12)
# inside Cyl
# (None, 5, 12, 6)
# out
# (None, 6, 5, 12)
# (None, 6, 5, 12, 8)
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 6, 1, 12, 8) 0
# __________________________________________________________________________________________________
# cylindrical_pad_lstmcnn_2 (Cyli (None, 6, 1, 16, 10) 0           input_2[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_2 (ConvLSTM2D)     (None, 6, 5, 12, 8)  1820        cylindrical_pad_lstmcnn_2[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 6, 5, 12)     0           conv_lst_m2d_2[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 6, 5, 12)     0           conv_lst_m2d_2[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 6, 5, 12)     0           conv_lst_m2d_2[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 6, 5, 12)     0           conv_lst_m2d_2[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 6, 5, 12)     0           conv_lst_m2d_2[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 6, 5, 12)     0           conv_lst_m2d_2[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 6, 5, 12)     0           conv_lst_m2d_2[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 6, 5, 12)     0           conv_lst_m2d_2[0][0]
# __________________________________________________________________________________________________
# permute_16 (Permute)            (None, 5, 12, 6)     0           lambda_16[0][0]
# __________________________________________________________________________________________________
# permute_18 (Permute)            (None, 5, 12, 6)     0           lambda_18[0][0]
# __________________________________________________________________________________________________
# permute_20 (Permute)            (None, 5, 12, 6)     0           lambda_20[0][0]
# __________________________________________________________________________________________________
# permute_22 (Permute)            (None, 5, 12, 6)     0           lambda_22[0][0]
# __________________________________________________________________________________________________
# permute_24 (Permute)            (None, 5, 12, 6)     0           lambda_24[0][0]
# __________________________________________________________________________________________________
# permute_26 (Permute)            (None, 5, 12, 6)     0           lambda_26[0][0]
# __________________________________________________________________________________________________
# permute_28 (Permute)            (None, 5, 12, 6)     0           lambda_28[0][0]
# __________________________________________________________________________________________________
# permute_30 (Permute)            (None, 5, 12, 6)     0           lambda_30[0][0]
# __________________________________________________________________________________________________
# conv2_0 (Conv2D)                (None, 4, 12, 6)     184         permute_16[0][0]
# __________________________________________________________________________________________________
# conv2_1 (Conv2D)                (None, 4, 12, 6)     184         permute_18[0][0]
# __________________________________________________________________________________________________
# conv2_2 (Conv2D)                (None, 4, 12, 6)     184         permute_20[0][0]
# __________________________________________________________________________________________________
# conv2_3 (Conv2D)                (None, 4, 12, 6)     184         permute_22[0][0]
# __________________________________________________________________________________________________
# conv2_4 (Conv2D)                (None, 4, 12, 6)     184         permute_24[0][0]
# __________________________________________________________________________________________________
# conv2_5 (Conv2D)                (None, 4, 12, 6)     184         permute_26[0][0]
# __________________________________________________________________________________________________
# conv2_6 (Conv2D)                (None, 4, 12, 6)     184         permute_28[0][0]
# __________________________________________________________________________________________________
# conv2_7 (Conv2D)                (None, 4, 12, 6)     184         permute_30[0][0]
# __________________________________________________________________________________________________
# conv_final_softmax_0 (Conv2D)   (None, 5, 12, 6)     85          conv2_0[0][0]
# __________________________________________________________________________________________________
# conv_final_softmax_1 (Conv2D)   (None, 5, 12, 6)     85          conv2_1[0][0]
# __________________________________________________________________________________________________
# conv_final_softmax_2 (Conv2D)   (None, 5, 12, 6)     85          conv2_2[0][0]
# __________________________________________________________________________________________________
# conv_final_softmax_3 (Conv2D)   (None, 5, 12, 6)     85          conv2_3[0][0]
# __________________________________________________________________________________________________
# conv_final_softmax_4 (Conv2D)   (None, 5, 12, 6)     85          conv2_4[0][0]
# __________________________________________________________________________________________________
# conv_final_softmax_5 (Conv2D)   (None, 5, 12, 6)     85          conv2_5[0][0]
# __________________________________________________________________________________________________
# conv_final_softmax_6 (Conv2D)   (None, 5, 12, 6)     85          conv2_6[0][0]
# __________________________________________________________________________________________________
# conv_final_softmax_7 (Conv2D)   (None, 5, 12, 6)     85          conv2_7[0][0]
# __________________________________________________________________________________________________
# permute_17 (Permute)            (None, 6, 5, 12)     0           conv_final_softmax_0[0][0]
# __________________________________________________________________________________________________
# permute_19 (Permute)            (None, 6, 5, 12)     0           conv_final_softmax_1[0][0]
# __________________________________________________________________________________________________
# permute_21 (Permute)            (None, 6, 5, 12)     0           conv_final_softmax_2[0][0]
# __________________________________________________________________________________________________
# permute_23 (Permute)            (None, 6, 5, 12)     0           conv_final_softmax_3[0][0]
# __________________________________________________________________________________________________
# permute_25 (Permute)            (None, 6, 5, 12)     0           conv_final_softmax_4[0][0]
# __________________________________________________________________________________________________
# permute_27 (Permute)            (None, 6, 5, 12)     0           conv_final_softmax_5[0][0]
# __________________________________________________________________________________________________
# permute_29 (Permute)            (None, 6, 5, 12)     0           conv_final_softmax_6[0][0]
# __________________________________________________________________________________________________
# permute_31 (Permute)            (None, 6, 5, 12)     0           conv_final_softmax_7[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 6, 5, 12, 1)  0           permute_17[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 6, 5, 12, 1)  0           permute_19[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 6, 5, 12, 1)  0           permute_21[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 6, 5, 12, 1)  0           permute_23[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 6, 5, 12, 1)  0           permute_25[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 6, 5, 12, 1)  0           permute_27[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 6, 5, 12, 1)  0           permute_29[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 6, 5, 12, 1)  0           permute_31[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 6, 5, 12, 8)  0           lambda_17[0][0]
#                                                                  lambda_19[0][0]
#                                                                  lambda_21[0][0]
#                                                                  lambda_23[0][0]
#                                                                  lambda_25[0][0]
#                                                                  lambda_27[0][0]
#                                                                  lambda_29[0][0]
#                                                                  lambda_31[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 6, 5, 12, 8)  0           conv_lst_m2d_2[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# cylindrical_pad_lstmcnn_3 (Cyli (None, 6, 5, 14, 14) 0           multiply_1[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_3 (ConvLSTM2D)     (None, 10, 12, 12)   5440        cylindrical_pad_lstmcnn_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1440)         0           conv_lst_m2d_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 5)            7205        flatten_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 5)            0           dense_1[0][0]
# ==================================================================================================
# Total params: 16,617
# Trainable params: 16,617
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from IPython.display import SVG,display
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
import matplotlib.pyplot as plt

#dá erro mas funciona 
#plot_model(model, to_file='model.pdf',show_shapes=True)

modelSVG=SVG(model_to_dot(model,show_shapes=True).create(prog='dot', format='svg'))
display(modelSVG)

# %%
# !ls -l
# Out:
# total 19000
# -rw-r--r-- 1 root root   440240 Dec  7 17:34 CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# -rw-r--r-- 1 root root    11504 Dec  7 17:22 out-class-size72-step12.csv
# drwxr-xr-x 1 root root     4096 Dec  2 22:04 sample_data
# -rw-r--r-- 1 root root 18994762 Dec  7 17:24 windows-size72-step12.csv

# %%
NB_EPOCH = 100
BATCH_SIZE = 64
VERBOSE = 1

#tbCallBack = TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True)
#esCallBack = EarlyStopping(monitor='val_acc', min_delta=0, patience=12, verbose=0, mode='max')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.01,patience=5, min_lr=0.0001)
best_checkpoint = ModelCheckpoint('CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5', monitor='val_accuracy', save_best_only=True, verbose=1)

history = model.fit(X_train, y_train, 
		batch_size=BATCH_SIZE, epochs=NB_EPOCH, 
		verbose=1, # 0 for no logging to stdout, 1 for progress bar logging, 2 for one log line per epoch.
		validation_data=(X_test,y_test),
		#validation_split=VALIDATION_SPLIT,
		callbacks=[best_checkpoint])
# Out:
# Epoch 1/100
# 36/36 [==============================] - ETA: 0s - loss: 1.6032 - accuracy: 0.2164
# Epoch 00001: val_accuracy improved from -inf to 0.17565, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# 36/36 [==============================] - 6s 170ms/step - loss: 1.6032 - accuracy: 0.2164 - val_loss: 1.6143 - val_accuracy: 0.1757
# Epoch 2/100
# 36/36 [==============================] - ETA: 0s - loss: 1.5113 - accuracy: 0.3216
# Epoch 00002: val_accuracy improved from 0.17565 to 0.27826, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# 36/36 [==============================] - 5s 149ms/step - loss: 1.5113 - accuracy: 0.3216 - val_loss: 1.4579 - val_accuracy: 0.2783
# Epoch 3/100
# 36/36 [==============================] - ETA: 0s - loss: 1.4612 - accuracy: 0.3572
# Epoch 00003: val_accuracy improved from 0.27826 to 0.29739, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# 36/36 [==============================] - 5s 147ms/step - loss: 1.4612 - accuracy: 0.3572 - val_loss: 1.5195 - val_accuracy: 0.2974
# Epoch 4/100
# 36/36 [==============================] - ETA: 0s - loss: 1.4379 - accuracy: 0.3603
# Epoch 00004: val_accuracy improved from 0.29739 to 0.31826, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# 36/36 [==============================] - 5s 149ms/step - loss: 1.4379 - accuracy: 0.3603 - val_loss: 1.4557 - val_accuracy: 0.3183
# Epoch 5/100
# 36/36 [==============================] - ETA: 0s - loss: 1.4207 - accuracy: 0.3681
# Epoch 00005: val_accuracy improved from 0.31826 to 0.32870, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# 36/36 [==============================] - 5s 150ms/step - loss: 1.4207 - accuracy: 0.3681 - val_loss: 1.4440 - val_accuracy: 0.3287
# Epoch 6/100
# 36/36 [==============================] - ETA: 0s - loss: 1.4135 - accuracy: 0.3664
# Epoch 00006: val_accuracy improved from 0.32870 to 0.33217, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# 36/36 [==============================] - 5s 146ms/step - loss: 1.4135 - accuracy: 0.3664 - val_loss: 1.4312 - val_accuracy: 0.3322
# Epoch 7/100
# 36/36 [==============================] - ETA: 0s - loss: 1.4021 - accuracy: 0.3907
# Epoch 00007: val_accuracy improved from 0.33217 to 0.36000, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# 36/36 [==============================] - 5s 148ms/step - loss: 1.4021 - accuracy: 0.3907 - val_loss: 1.4195 - val_accuracy: 0.3600
# Epoch 8/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3889 - accuracy: 0.3907
# Epoch 00008: val_accuracy did not improve from 0.36000
# 36/36 [==============================] - 5s 144ms/step - loss: 1.3889 - accuracy: 0.3907 - val_loss: 1.4096 - val_accuracy: 0.3478
# Epoch 9/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3863 - accuracy: 0.3985
# Epoch 00009: val_accuracy did not improve from 0.36000
# 36/36 [==============================] - 5s 144ms/step - loss: 1.3863 - accuracy: 0.3985 - val_loss: 1.4238 - val_accuracy: 0.3391
# Epoch 10/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3847 - accuracy: 0.4020
# Epoch 00010: val_accuracy improved from 0.36000 to 0.36696, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# 36/36 [==============================] - 5s 146ms/step - loss: 1.3847 - accuracy: 0.4020 - val_loss: 1.3969 - val_accuracy: 0.3670
# Epoch 11/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3856 - accuracy: 0.3894
# Epoch 00011: val_accuracy did not improve from 0.36696
# 36/36 [==============================] - 5s 140ms/step - loss: 1.3856 - accuracy: 0.3894 - val_loss: 1.4036 - val_accuracy: 0.3635
# Epoch 12/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3766 - accuracy: 0.4011
# Epoch 00012: val_accuracy did not improve from 0.36696
# 36/36 [==============================] - 5s 140ms/step - loss: 1.3766 - accuracy: 0.4011 - val_loss: 1.4160 - val_accuracy: 0.3565
# Epoch 13/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3709 - accuracy: 0.3977
# Epoch 00013: val_accuracy improved from 0.36696 to 0.37043, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# 36/36 [==============================] - 5s 143ms/step - loss: 1.3709 - accuracy: 0.3977 - val_loss: 1.3948 - val_accuracy: 0.3704
# Epoch 14/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3676 - accuracy: 0.4072
# Epoch 00014: val_accuracy improved from 0.37043 to 0.38087, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# 36/36 [==============================] - 5s 140ms/step - loss: 1.3676 - accuracy: 0.4072 - val_loss: 1.3928 - val_accuracy: 0.3809
# Epoch 15/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3644 - accuracy: 0.4046
# Epoch 00015: val_accuracy did not improve from 0.38087
# 36/36 [==============================] - 5s 140ms/step - loss: 1.3644 - accuracy: 0.4046 - val_loss: 1.3852 - val_accuracy: 0.3670
# Epoch 16/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3651 - accuracy: 0.4098
# Epoch 00016: val_accuracy did not improve from 0.38087
# 36/36 [==============================] - 5s 137ms/step - loss: 1.3651 - accuracy: 0.4098 - val_loss: 1.3902 - val_accuracy: 0.3530
# Epoch 17/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3608 - accuracy: 0.3981
# Epoch 00017: val_accuracy did not improve from 0.38087
# 36/36 [==============================] - 5s 147ms/step - loss: 1.3608 - accuracy: 0.3981 - val_loss: 1.3973 - val_accuracy: 0.3513
# Epoch 18/100
# 36/36 [==============================] - ETA: 0s - loss: 1.
100
# 36/36 [==============================] - ETA: 0s - loss: 1.2806 - accuracy: 0.4446
# Epoch 00066: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 5s 146ms/step - loss: 1.2806 - accuracy: 0.4446 - val_loss: 1.3440 - val_accuracy: 0.4070
# Epoch 67/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2732 - accuracy: 0.4450
# Epoch 00067: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 5s 145ms/step - loss: 1.2732 - accuracy: 0.4450 - val_loss: 1.3500 - val_accuracy: 0.3843
# Epoch 68/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2698 - accuracy: 0.4502
# Epoch 00068: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 5s 146ms/step - loss: 1.2698 - accuracy: 0.4502 - val_loss: 1.3373 - val_accuracy: 0.4017
# Epoch 69/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2714 - accuracy: 0.4411
# Epoch 00069: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 5s 145ms/step - loss: 1.2714 - accuracy: 0.4411 - val_loss: 1.3444 - val_accuracy: 0.4035
# Epoch 70/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2709 - accuracy: 0.4429
# Epoch 00070: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 5s 143ms/step - loss: 1.2709 - accuracy: 0.4429 - val_loss: 1.3341 - val_accuracy: 0.3983
# Epoch 71/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2697 - accuracy: 0.4559
# Epoch 00071: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 5s 145ms/step - loss: 1.2697 - accuracy: 0.4559 - val_loss: 1.3412 - val_accuracy: 0.4070
# Epoch 72/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2721 - accuracy: 0.4446
# Epoch 00072: val_accuracy did not improve from 0.40870
# 36/36 [==============================] - 5s 147ms/step - loss: 1.2721 - accuracy: 0.4446 - val_loss: 1.3445 - val_accuracy: 0.3965
# Epoch 73/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2617 - accuracy: 0.4489
# Epoch 00073: val_accuracy improved from 0.40870 to 0.41217, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# 36/36 [==============================] - 5s 147ms/step - loss: 1.2617 - accuracy: 0.4489 - val_loss: 1.3303 - val_accuracy: 0.4122
# Epoch 74/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2786 - accuracy: 0.4355
# Epoch 00074: val_accuracy did not improve from 0.41217
# 36/36 [==============================] - 5s 145ms/step - loss: 1.2786 - accuracy: 0.4355 - val_loss: 1.3414 - val_accuracy: 0.4087
# Epoch 75/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2694 - accuracy: 0.4463
# Epoch 00075: val_accuracy did not improve from 0.41217
# 36/36 [==============================] - 5s 147ms/step - loss: 1.2694 - accuracy: 0.4463 - val_loss: 1.3415 - val_accuracy: 0.3965
# Epoch 76/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2671 - accuracy: 0.4563
# Epoch 00076: val_accuracy did not improve from 0.41217
# 36/36 [==============================] - 5s 146ms/step - loss: 1.2671 - accuracy: 0.4563 - val_loss: 1.3475 - val_accuracy: 0.4104
# Epoch 77/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2625 - accuracy: 0.4472
# Epoch 00077: val_accuracy did not improve from 0.41217
# 36/36 [==============================] - 5s 148ms/step - loss: 1.2625 - accuracy: 0.4472 - val_loss: 1.3511 - val_accuracy: 0.3930
# Epoch 78/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2740 - accuracy: 0.4455
# Epoch 00078: val_accuracy improved from 0.41217 to 0.42261, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# 36/36 [==============================] - 5s 147ms/step - loss: 1.2740 - accuracy: 0.4455 - val_loss: 1.3331 - val_accuracy: 0.4226
# Epoch 79/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2680 - accuracy: 0.4459
# Epoch 00079: val_accuracy did not improve from 0.42261
# 36/36 [==============================] - 5s 145ms/step - loss: 1.2680 - accuracy: 0.4459 - val_loss: 1.3475 - val_accuracy: 0.4000
# Epoch 80/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2649 - accuracy: 0.4537
# Epoch 00080: val_accuracy did not improve from 0.42261
# 36/36 [==============================] - 5s 142ms/step - loss: 1.2649 - accuracy: 0.4537 - val_loss: 1.3426 - val_accuracy: 0.4157
# Epoch 81/100
# 36/36 [==============================] - ETA: 0s - loss: 1.
100
# 36/36 [==============================] - ETA: 0s - loss: 1.2284 - accuracy: 0.4781
# Epoch 00098: val_accuracy did not improve from 0.42261
# 36/36 [==============================] - 5s 145ms/step - loss: 1.2284 - accuracy: 0.4781 - val_loss: 1.3459 - val_accuracy: 0.4226
# Epoch 99/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2253 - accuracy: 0.4728
# Epoch 00099: val_accuracy did not improve from 0.42261
# 36/36 [==============================] - 5s 145ms/step - loss: 1.2253 - accuracy: 0.4728 - val_loss: 1.3535 - val_accuracy: 0.4017
# Epoch 100/100
# 36/36 [==============================] - ETA: 0s - loss: 1.2321 - accuracy: 0.4633
# Epoch 00100: val_accuracy did not improve from 0.42261
# 36/36 [==============================] - 5s 145ms/step - loss: 1.2321 - accuracy: 0.4633 - val_loss: 1.3605 - val_accuracy: 0.3930

# %%
import json,codecs
import numpy as np
def saveHist(path,history):
 
    new_hist = {}
    for key in list(history.history.keys()):
        if type(history.history[key]) == np.ndarray:
            new_hist[key] == history.history[key].tolist()
        elif type(history.history[key]) == list:
           #if  type(history.history[key][0]) == np.float64:
           new_hist[key] = list(map(float, history.history[key]))
 
    #print(new_hist)
    with codecs.open(path, 'w', encoding='utf-8') as f:
        json.dump(new_hist, f, separators=(',', ':'), sort_keys=True, indent=4) 
 
def loadHist(path):
    with codecs.open(path, 'r', encoding='utf-8') as f:
        n = json.loads(f.read())
    return n
 

saveHist('CNNLSTM-ROLL-ATTENTION-BF-SPLIT-polution.hist',history)
hist=loadHist('CNNLSTM-ROLL-ATTENTION-BF-SPLIT-polution.hist')

# %%
import matplotlib.pylab as plt

acc=np.array(hist['accuracy'])
#acc=acc[0:100]
#acc=np.append(acc,[0.7])
plt.plot(acc,'b--')
plt.plot(hist['val_accuracy'],'b',label='CNNLSTM')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.show()
# summarize history for loss
loss=np.array(hist['loss'])
#loss=np.append(loss,[2])
plt.plot(loss,'b--',label='train')
plt.plot(hist['val_loss'],'b',label='test')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from keras.models import load_model
model = load_model('CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-polution.h5',custom_objects={'CylindricalPadLSTMCNN':CylindricalPadLSTMCNN})

# %%
from sklearn.metrics import classification_report, confusion_matrix

	
print('Confusion Matrix')
cm=confusion_matrix(np.argmax(y_test,axis=1), np.argmax(model.predict(X_test),axis=1))
print(cm)
scores = model.evaluate(X_test,y_test, verbose=0)
print("Dados Validação %s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

pred = model.predict(X_test)
predicted = np.argmax(pred, axis=1)
report = classification_report(np.argmax(y_test, axis=1), predicted,digits=4)
print(report)
# Out:
# Confusion Matrix
# [[80 26  4  5  0]
#  [29 80 18  5 10]
#  [16 61 29 21 13]
#  [ 4 30 22 30 22]
#  [ 6 11 11 18 24]]
# Dados Validação accuracy: 42.26%
#               precision    recall  f1-score   support
#
#            0     0.5926    0.6957    0.6400       115
#            1     0.3846    0.5634    0.4571       142
#            2     0.3452    0.2071    0.2589       140
#            3     0.3797    0.2778    0.3209       108
#            4     0.3478    0.3429    0.3453        70
#
#     accuracy                         0.4226       575
#    macro avg     0.4100    0.4174    0.4045       575
# weighted avg     0.4112    0.4226    0.4062       575

# %%
import seaborn as sns

def cm_analysis(y_true, y_pred, labels, ymap=None, figsize=(10,10)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels = [ymap[yi] for yi in labels]
    cm = confusion_matrix(y_true, y_pred)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    plt.savefig("LSTM-ATTENTION-CONV1D-BF-enegie.pdf")
    plt.show()
    
    
    
cm_analysis(np.argmax(y_test,axis=1),np.argmax(pred,axis=1), labels=["1","2","3","4","5"], ymap=None, figsize=(6,6))
